# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;">Récuperation de la liste des DGEFP</span>

# %%
import requests

dataset_id = "liste-publique-des-of-v2"
export_url = f"https://dgefp.opendatasoft.com/api/v2/catalog/datasets/{dataset_id}/exports/csv"
params = {
    "delimiter": ";",  
    "list_separator": ",", 
    "quote_all": "false", 
    "with_bom": "true" 
}

response = requests.get(export_url, params=params)

if response.status_code == 200:
    csv_path = 'all_records_export.csv'
    with open(csv_path, 'wb') as file:
        file.write(response.content)
    print(f"Les enregistrements ont été exportés et sauvegardés dans '{csv_path}'.")
else:
    print(f"Erreur lors de l'exportation : {response.status_code}")
# Out:
# Les enregistrements ont été exportés et sauvegardés dans 'all_records_export.csv'.

# %%
import pandas as pd

csv_path = 'all_records_export.csv'

try:
    df = pd.read_csv(csv_path, delimiter=';')
    print(df.head())
    print(f"Nombre total d'enregistrements exportés : {df.shape[0]}")
    print(f"Nombre total de colonnes : {df.shape[1]}")
except FileNotFoundError:
    print(f"Le fichier '{csv_path}' n'existe pas.")
except Exception as e:
    print(f"Une erreur s'est produite : {e}")
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13304\4057669730.py:6: DtypeWarning: Columns (0,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, delimiter=';')
#   numerodeclarationactivite numerosdeclarationactiviteprecedent  \
# 0               11788457578                         11788457578
# 1               11756782875             11930571893,11756782875
# 2               11922694992                         11922694992
# 3               93061133106                         93061133106
# 4               93050103005                         93050103005
#
#        denomination      siren  siretetablissementdeclarant  \
# 0         01 AFFORP  890176654               89017665400014
# 1       01 CONTROLE  335060307               33506030700063
# 2     01 CQFD AUDIT  894612175               89461217500014
# 3            01MARS  801880683               80188068300025
# 4  05 VERIFICATIONS  821646213               82164621300024
#
#               adressephysiqueorganismeformation_voie  \
# 0                                                NaN
# 1                            106 AV PHILIPPE AUGUSTE
# 2                               33  RUE ANNA JACQUIN
# 3                            84  RUE MARECHAL JOFFRE
# 4  RUE BELLE AUREILLE N F107 BAT FERME BELLE AURE...
#
#    adressephysiqueorganismeformation_codepostal  \
# 0                                           NaN
# 1                                       75011.0
# 2                                       92100.0
# 3                                        6000.0
# 4                                        5000.0
#
#   adressephysiqueorganismeformation_ville  \
# 0                                     NaN
# 1                                PARIS 11
# 2                    BOULOGNE BILLANCOURT
# 3                                    NICE
# 4                                     GAP
#
#    adressephysiqueorganismeformation_coderegion         geocodageban  ...  \
# 0                                            11                  NaN  ...
# 1                                            11  48.856517, 2.391101  ...
# 2                                            11  48.844944, 2.228016  ...
# 3                                            93  43.697144, 7.257563  ...
# 4                                            93  44.535381, 6.052914  ...
#
#      epci_code                                       epci_name dep_code  \
# 0          NaN                                             NaN      NaN
# 1  200054781.0                        Métropole du Grand Paris       75
# 2  200054781.0                        Métropole du Grand Paris       92
# 3  200030195.0                      Métropole Nice Côte d'Azur       06
# 4  200067825.0  Communauté d'agglomération Gap-Tallard-Durance       05
#
#             dep_name                    reg_name reg_code  \
# 0  Pas de départment               Île-de-France       11
# 1              Paris               Île-de-France       11
# 2     Hauts-de-Seine               Île-de-France       11
# 3    Alpes-Maritimes  Provence-Alpes-Côte d'Azur       93
# 4       Hautes-Alpes  Provence-Alpes-Côte d'Azur       93
#
#                                   toutes_specialites  \
# 0                               Formations générales
# 1  Electricité, électronique (non compris automat...
# 2                              Comptabilité, gestion
# 3      Spécialités plurivalentes de la communication
# 4  Electricité, électronique (non compris automat...
#
#   organisme_formation_geocode                               certifications  \
# 0                       False  Actions de formations,Bilans de compétences
# 1                        True                        Actions de formations
# 2                        True                                          NaN
# 3                        True                                          NaN
# 4                        True                        Actions de formations
#
#    random_id
# 0  36.926121
# 1  88.702101
# 2  12.214291
# 3  79.460767
# 4  82.376970
#
# [5 rows x 43 columns]
# Nombre total d'enregistrements exportés : 134408
# Nombre total de colonnes : 43

# %%
df.to_csv("listesdesqualiopietnon.csv", index=False)
df
# Out:
#        numerodeclarationactivite numerosdeclarationactiviteprecedent  \
# 0                    11788457578                         11788457578
# 1                    11756782875             11930571893,11756782875
# 2                    11922694992                         11922694992
# 3                    93061133106                         93061133106
# 4                    93050103005                         93050103005
# ...                          ...                                 ...
# 134403               28760673976             75331298733,28760673976
# 134404               52490291549                         52490291549
# 134405               41570304557             11930118993,41570304557
# 134406               11788581278                         11788581278
# 134407               11755090675                         11755090675
#
#               denomination      siren  siretetablissementdeclarant  \
# 0                01 AFFORP  890176654               89017665400014
# 1              01 CONTROLE  335060307               33506030700063
# 2            01 CQFD AUDIT  894612175               89461217500014
# 3                   01MARS  801880683               80188068300025
# 4         05 VERIFICATIONS  821646213               82164621300024
# ...                    ...        ...                          ...
# 134403  ZVENIGOROSKY IRENE  832033559               83203355900036
# 134404           ZW FRANCE  531876670               53187667000013
# 134405          ZWICKROELL  315547927               31554792700063
# 134406               ZYBRA  878152065               87815206500016
# 134407          Z. YOUAKIM  539019943               53901994300031
#
#                    adressephysiqueorganismeformation_voie  \
# 0                                                     NaN
# 1                                 106 AV PHILIPPE AUGUSTE
# 2                                    33  RUE ANNA JACQUIN
# 3                                 84  RUE MARECHAL JOFFRE
# 4       RUE BELLE AUREILLE N F107 BAT FERME BELLE AURE...
# ...                                                   ...
# 134403                             140 ALLÉE DES BUISSONS
# 134404                                                NaN
# 134405            4 Rue Royal Canadian Air Force CS 45191
# 134406                                3 CHE DES CARRIERES
# 134407                                                NaN
#
#         adressephysiqueorganismeformation_codepostal  \
# 0                                                NaN
# 1                                            75011.0
# 2                                            92100.0
# 3                                             6000.0
# 4                                             5000.0
# ...                                              ...
# 134403                                       76160.0
# 134404                                           NaN
# 134405                                       57075.0
# 134406                                       78540.0
# 134407                                           NaN
#
#        adressephysiqueorganismeformation_ville  \
# 0                                          NaN
# 1                                     PARIS 11
# 2                         BOULOGNE BILLANCOURT
# 3                                         NICE
# 4                                          GAP
# ...                                        ...
# 134403                                  PREAUX
# 134404                                     NaN
# 134405                           ARS LAQUENEXY
# 134406                             VERNOUILLET
# 134407                                     NaN
#
#         adressephysiqueorganismeformation_coderegion         geocodageban  \
# 0                                                 11                  NaN
# 1                                                 11  48.856517, 2.391101
# 2                                                 11  48.844944, 2.228016
# 3                                                 93  43.697144, 7.257563
# 4                                                 93  44.535381, 6.052914
# ...                                              ...                  ...
# 134403                                            28  49.487453, 1.215396
# 134404                                            52                  NaN
# 134405                                            44                  NaN
# 134406                                            11  48.967265, 1.985073
# 134407                                            11                  NaN
#
#         ...    epci_code                                       epci_name  \
# 0       ...          NaN                                             NaN
# 1       ...  200054781.0                        Métropole du Grand Paris
# 2       ...  200054781.0                        Métropole du Grand Paris
# 3       ...  200030195.0                      Métropole Nice Côte d'Azur
# 4       ...  200067825.0  Communauté d'agglomération Gap-Tallard-Durance
# ...     ...          ...                                             ...
# 134403  ...  200070449.0         Communauté de communes Inter-Caux-Vexin
# 134404  ...          NaN                                             NaN
# 134405  ...          NaN                                             NaN
# 134406  ...  200059889.0    Communauté urbaine Grand Paris Seine et Oise
# 134407  ...          NaN                                             NaN
#
#        dep_code           dep_name                    reg_name reg_code  \
# 0           NaN  Pas de départment               Île-de-France       11
# 1            75              Paris               Île-de-France       11
# 2            92     Hauts-de-Seine               Île-de-France       11
# 3            06    Alpes-Maritimes  Provence-Alpes-Côte d'Azur       93
# 4            05       Hautes-Alpes  Provence-Alpes-Côte d'Azur       93
# ...         ...                ...                         ...      ...
# 134403       76     Seine-Maritime                   Normandie       28
# 134404      NaN  Pas de départment            Pays de la Loire       52
# 134405      NaN  Pas de départment                   Grand Est       44
# 134406       78           Yvelines               Île-de-France       11
# 134407      NaN  Pas de départment               Île-de-France       11
#
#                                        toutes_specialites  \
# 0                                    Formations générales
# 1       Electricité, électronique (non compris automat...
# 2                                   Comptabilité, gestion
# 3           Spécialités plurivalentes de la communication
# 4       Electricité, électronique (non compris automat...
# ...                                                   ...
# 134403                                              Santé
# 134404  Formations générales,Informatique, traitement ...
# 134405  Métallurgie (y compris sidérurgie, fonderie, n...
# 134406                            Enseignement, formation
# 134407  Développement des capacités comportementales e...
#
#        organisme_formation_geocode  \
# 0                            False
# 1                             True
# 2                             True
# 3                             True
# 4                             True
# ...                            ...
# 134403                        True
# 134404                       False
# 134405                       False
# 134406                        True
# 134407                       False
#
#                                      certifications  random_id
# 0       Actions de formations,Bilans de compétences  36.926121
# 1                             Actions de formations  88.702101
# 2                                               NaN  12.214291
# 3                                               NaN  79.460767
# 4                             Actions de formations  82.376970
# ...                                             ...        ...
# 134403                                          NaN  68.394827
# 134404                        Actions de formations  76.086346
# 134405                                          NaN  13.087755
# 134406                                          NaN  97.731259
# 134407                                          NaN  39.436185
#
# [134408 rows x 43 columns]

# %%
df
# Out:
#        numerodeclarationactivite numerosdeclarationactiviteprecedent  \
# 0                    11788457578                         11788457578
# 1                    11756782875             11930571893,11756782875
# 2                    11922694992                         11922694992
# 3                    93061133106                         93061133106
# 4                    93050103005                         93050103005
# ...                          ...                                 ...
# 134403               28760673976             75331298733,28760673976
# 134404               52490291549                         52490291549
# 134405               41570304557             11930118993,41570304557
# 134406               11788581278                         11788581278
# 134407               11755090675                         11755090675
#
#               denomination      siren  siretetablissementdeclarant  \
# 0                01 AFFORP  890176654               89017665400014
# 1              01 CONTROLE  335060307               33506030700063
# 2            01 CQFD AUDIT  894612175               89461217500014
# 3                   01MARS  801880683               80188068300025
# 4         05 VERIFICATIONS  821646213               82164621300024
# ...                    ...        ...                          ...
# 134403  ZVENIGOROSKY IRENE  832033559               83203355900036
# 134404           ZW FRANCE  531876670               53187667000013
# 134405          ZWICKROELL  315547927               31554792700063
# 134406               ZYBRA  878152065               87815206500016
# 134407          Z. YOUAKIM  539019943               53901994300031
#
#                    adressephysiqueorganismeformation_voie  \
# 0                                                     NaN
# 1                                 106 AV PHILIPPE AUGUSTE
# 2                                    33  RUE ANNA JACQUIN
# 3                                 84  RUE MARECHAL JOFFRE
# 4       RUE BELLE AUREILLE N F107 BAT FERME BELLE AURE...
# ...                                                   ...
# 134403                             140 ALLÉE DES BUISSONS
# 134404                                                NaN
# 134405            4 Rue Royal Canadian Air Force CS 45191
# 134406                                3 CHE DES CARRIERES
# 134407                                                NaN
#
#         adressephysiqueorganismeformation_codepostal  \
# 0                                                NaN
# 1                                            75011.0
# 2                                            92100.0
# 3                                             6000.0
# 4                                             5000.0
# ...                                              ...
# 134403                                       76160.0
# 134404                                           NaN
# 134405                                       57075.0
# 134406                                       78540.0
# 134407                                           NaN
#
#        adressephysiqueorganismeformation_ville  \
# 0                                          NaN
# 1                                     PARIS 11
# 2                         BOULOGNE BILLANCOURT
# 3                                         NICE
# 4                                          GAP
# ...                                        ...
# 134403                                  PREAUX
# 134404                                     NaN
# 134405                           ARS LAQUENEXY
# 134406                             VERNOUILLET
# 134407                                     NaN
#
#         adressephysiqueorganismeformation_coderegion         geocodageban  \
# 0                                                 11                  NaN
# 1                                                 11  48.856517, 2.391101
# 2                                                 11  48.844944, 2.228016
# 3                                                 93  43.697144, 7.257563
# 4                                                 93  44.535381, 6.052914
# ...                                              ...                  ...
# 134403                                            28  49.487453, 1.215396
# 134404                                            52                  NaN
# 134405                                            44                  NaN
# 134406                                            11  48.967265, 1.985073
# 134407                                            11                  NaN
#
#         ...    epci_code                                       epci_name  \
# 0       ...          NaN                                             NaN
# 1       ...  200054781.0                        Métropole du Grand Paris
# 2       ...  200054781.0                        Métropole du Grand Paris
# 3       ...  200030195.0                      Métropole Nice Côte d'Azur
# 4       ...  200067825.0  Communauté d'agglomération Gap-Tallard-Durance
# ...     ...          ...                                             ...
# 134403  ...  200070449.0         Communauté de communes Inter-Caux-Vexin
# 134404  ...          NaN                                             NaN
# 134405  ...          NaN                                             NaN
# 134406  ...  200059889.0    Communauté urbaine Grand Paris Seine et Oise
# 134407  ...          NaN                                             NaN
#
#        dep_code           dep_name                    reg_name reg_code  \
# 0           NaN  Pas de départment               Île-de-France       11
# 1            75              Paris               Île-de-France       11
# 2            92     Hauts-de-Seine               Île-de-France       11
# 3            06    Alpes-Maritimes  Provence-Alpes-Côte d'Azur       93
# 4            05       Hautes-Alpes  Provence-Alpes-Côte d'Azur       93
# ...         ...                ...                         ...      ...
# 134403       76     Seine-Maritime                   Normandie       28
# 134404      NaN  Pas de départment            Pays de la Loire       52
# 134405      NaN  Pas de départment                   Grand Est       44
# 134406       78           Yvelines               Île-de-France       11
# 134407      NaN  Pas de départment               Île-de-France       11
#
#                                        toutes_specialites  \
# 0                                    Formations générales
# 1       Electricité, électronique (non compris automat...
# 2                                   Comptabilité, gestion
# 3           Spécialités plurivalentes de la communication
# 4       Electricité, électronique (non compris automat...
# ...                                                   ...
# 134403                                              Santé
# 134404  Formations générales,Informatique, traitement ...
# 134405  Métallurgie (y compris sidérurgie, fonderie, n...
# 134406                            Enseignement, formation
# 134407  Développement des capacités comportementales e...
#
#        organisme_formation_geocode  \
# 0                            False
# 1                             True
# 2                             True
# 3                             True
# 4                             True
# ...                            ...
# 134403                        True
# 134404                       False
# 134405                       False
# 134406                        True
# 134407                       False
#
#                                      certifications  random_id
# 0       Actions de formations,Bilans de compétences  36.926121
# 1                             Actions de formations  88.702101
# 2                                               NaN  12.214291
# 3                                               NaN  79.460767
# 4                             Actions de formations  82.376970
# ...                                             ...        ...
# 134403                                          NaN  68.394827
# 134404                        Actions de formations  76.086346
# 134405                                          NaN  13.087755
# 134406                                          NaN  97.731259
# 134407                                          NaN  39.436185
#
# [134408 rows x 43 columns]

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;">Récuperation de la liste des entreprises - Yav</span>

# %%
import time
import configparser
import requests
import pandas as pd

def CrmBitrix(content='', params=[], result='', pause_duration=1, max_retries=3):
    config = configparser.ConfigParser()
    config.read('Config.ini')

    if 'BITRIX' not in config:
        raise ValueError('Section BITRIX manquante dans le fichier \'config.ini\'')

    BITRIX_DOMAIN = config.get('BITRIX', 'BITRIX_DOMAIN')
    BITRIX_TOKEN = config.get('BITRIX', 'BITRIX_TOKEN')

    if not BITRIX_DOMAIN or not BITRIX_TOKEN:
        raise ValueError('Domain et/ou token Bitrix manquants dans le fichier \'config.ini\'')

    params_str = '&'.join(params)
    BitrixUrl = f'https://{BITRIX_DOMAIN}/rest/1/{BITRIX_TOKEN}/{content}?{params_str}&start='
    
    listIds, listTITLE, listEmails, listNumeros, listDATE_CREATE = [], [], [], [], []
    listActivite1, listActivite2, listActivite3 = [], [], []
    listAdresse, listCodePostale, listVille, listId, listSiret, listidd = [], [], [], [],[], []

    start = 0
    while True:
        url = BitrixUrl + str(start)
        for attempt in range(max_retries):
            try:
                response = requests.get(url)
                response.raise_for_status()
                break  
            except requests.exceptions.HTTPError as e:
                if response.status_code == 429:
                    wait_time = pause_duration * (2 ** attempt)
                    print(f'Rate limit exceeded. Retrying in {wait_time} seconds...')
                    time.sleep(wait_time)
                else:
                    raise ValueError(f'Erreur lors de la récupération depuis Bitrix : {e}')
            except requests.exceptions.RequestException as e:
                raise ValueError(f'Erreur lors de la récupération depuis Bitrix : {e}')

        

        data = response.json()
        if 'result' in data:
            contacts = data['result']
            for contact in contacts:
                if result == 'email':
                    if 'EMAIL' in contact:
                        email = contact['EMAIL'][0]['VALUE']
                        listEmails.append(email)
                        if 'PHONE' in contact:
                            mesNumeros = contact['PHONE'][0]['VALUE']
                            listNumeros.append(mesNumeros)
                        else:
                            listNumeros.append('')
                        
                elif result == 'title': 
                    listTITLE.append(contact.get('TITLE', ''))
                    listEmails.append(contact.get('EMAIL', [{}])[0].get('VALUE', ''))
                    listNumeros.append(contact.get('PHONE', [{}])[0].get('VALUE', ''))
                    listId.append(contact.get('ID', ''))
                    listActivite1.append(contact.get('UF_CRM_1686295056', ''))
                    listActivite2.append(contact.get('UF_CRM_1686295079', ''))
                    listActivite3.append(contact.get('UF_CRM_1686295100', ''))
                    listAdresse.append(contact.get('UF_CRM_1686295131', ''))
                    listCodePostale.append(contact.get('UF_CRM_1686295169', ''))
                    listVille.append(contact.get('UF_CRM_1686295194', ''))
                    listDATE_CREATE.append(contact.get('DATE_CREATE', ''))
                    listSiret.append(contact.get('UF_CRM_1686295022', ''))
                    listidd.append(contact.get('UF_CRM_1722346888', ''))
                else:
                    return 'Erreur avec les données attendues. Merci de vérifier la variable \'result\'.'

        if 'next' in data:
            start = data['next']
        else:
            break

    if result == 'email':
        df_btx = pd.DataFrame({'email': listEmails, 'phone': listNumeros})
    elif result == 'title':
        df_btx = pd.DataFrame({
            'ID': listId,
            'CompanyId': listId,
            'nom': listTITLE,
            "Email": listEmails,
            "Crée": listDATE_CREATE,
            "Mobile": listNumeros,
            "Activite1": listActivite1,
            "Activite2": listActivite2,
            "Activite3": listActivite3,
            "Adresse": listAdresse,
            "CodePostale": listCodePostale,
            "Ville": listVille,
            "Siret": listSiret,
            "IDS": listidd
        })
    else:
        return 'Erreur avec les données attendues. Merci de vérifier la variable \'result\'.'

    return df_btx


dfb = CrmBitrix(
    content='crm.company.list.json',
    params=[
        'select[]=ID',
        'select[]=ID',
        'select[]=TITLE',
        'select[]=EMAIL',
        'select[]=DATE_CREATE',
        'select[]=UF_CRM_1686295056',
        'select[]=UF_CRM_1686295079',
        'select[]=UF_CRM_1686295100',
        'select[]=UF_CRM_1686295131',
        'select[]=UF_CRM_1686295169',
        'select[]=UF_CRM_1686295194', 
        'select[]=UF_CRM_1686295022',
        'select[]=UF_CRM_1722346888',
        
    ],
    result="title"
)
dfb
# Out:
#            ID CompanyId                                             nom  \
# 0           4         4                  0CEAN INDIEN INFORMATIQUE SARL
# 1           8         8                                         0'LISTY
# 2          10        10                              1000 ET DEUX IDEES
# 3          12        12         1000 JOURS POUR NAITRE ET GRANDIR EGAUX
# 4          16        16                                    1001 TAILLES
# ...       ...       ...                                             ...
# 43319  157234    157234        ASSOC DEVELOP INFORMAT ADMINISTRAT JURID
# 43320  157236    157236                                   ADH FORMATION
# 43321  157238    157238  ANNE WATKIN L'ATELIER MARQUE PAGE  COACH SCOLA
# 43322  157242    157242                           ATELIERS PETITS DOMES
# 43323  157254    157254                                      Sans titre
#
#                                       Email                       Crée Mobile  \
# 0      contact@0ceanindienifnormatioque.cfr  2023-06-09T10:32:19+03:00
# 1                                            2023-06-09T10:32:19+03:00
# 2                                            2023-06-09T10:32:20+03:00
# 3                                            2023-06-09T10:32:20+03:00
# 4                                            2023-06-09T10:32:20+03:00
# ...                                     ...                        ...    ...
# 43319                                        2024-04-24T18:02:49+03:00
# 43320                                        2024-04-24T18:04:22+03:00
# 43321                                        2024-04-26T12:50:05+03:00
# 43322         atelierspetitsdomes@gmail.com  2024-05-17T18:19:54+03:00
# 43323                  edlotushom@gmail.com  2024-07-22T15:28:01+03:00
#
#                                                Activite1  \
# 0      Spécialités plurivalentes des échanges et de l...
# 1                                              Autres...
# 2                           Journalisme et communication
# 3                                                  Santé
# 4                  Habillement (y compris mode, couture)
# ...                                                  ...
# 43319                                               None
# 43320                                               None
# 43321                                               None
# 43322                                               None
# 43323                                               None
#
#                                                Activite2  \
# 0      Informatique, traitement de l'information, rés...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 43319                                               None
# 43320                                               None
# 43321                                               None
# 43322                                               None
# 43323                                               None
#
#                      Activite3                   Adresse CodePostale  \
# 0      Enseignement, formation                      None        None
# 1                         None  16 avenue Nelson Mandela       97227
# 2                         None     17 RUE DE BROCELIANDE       35360
# 3                         None             6 RUE FERRERE       33000
# 4                         None                      None        None
# ...                        ...                       ...         ...
# 43319                     None                      None        None
# 43320                     None                      None        None
# 43321                     None                      None        None
# 43322                     None                      None        None
# 43323                     None                      None        None
#
#               Ville           Siret   IDS
# 0              None  38452004500046   140
# 1          STE ANNE  88943425400013   140
# 2      BOISGERVILLY  51202144500014   140
# 3          BORDEAUX  88196598200013   140
# 4              None  52815239000019   140
# ...             ...             ...   ...
# 43319          None            None  None
# 43320          None            None   146
# 43321          None            None   146
# 43322          None            None  None
# 43323          None            None   146
#
# [43324 rows x 14 columns]

# %%
dfb.to_csv("company.csv", index=False)
dfb.drop_duplicates()
dfb
# Out:
#            ID CompanyId                                             nom  \
# 0           4         4                  0CEAN INDIEN INFORMATIQUE SARL
# 1           8         8                                         0'LISTY
# 2          10        10                              1000 ET DEUX IDEES
# 3          12        12         1000 JOURS POUR NAITRE ET GRANDIR EGAUX
# 4          16        16                                    1001 TAILLES
# ...       ...       ...                                             ...
# 43319  157234    157234        ASSOC DEVELOP INFORMAT ADMINISTRAT JURID
# 43320  157236    157236                                   ADH FORMATION
# 43321  157238    157238  ANNE WATKIN L'ATELIER MARQUE PAGE  COACH SCOLA
# 43322  157242    157242                           ATELIERS PETITS DOMES
# 43323  157254    157254                                      Sans titre
#
#                                       Email                       Crée Mobile  \
# 0      contact@0ceanindienifnormatioque.cfr  2023-06-09T10:32:19+03:00
# 1                                            2023-06-09T10:32:19+03:00
# 2                                            2023-06-09T10:32:20+03:00
# 3                                            2023-06-09T10:32:20+03:00
# 4                                            2023-06-09T10:32:20+03:00
# ...                                     ...                        ...    ...
# 43319                                        2024-04-24T18:02:49+03:00
# 43320                                        2024-04-24T18:04:22+03:00
# 43321                                        2024-04-26T12:50:05+03:00
# 43322         atelierspetitsdomes@gmail.com  2024-05-17T18:19:54+03:00
# 43323                  edlotushom@gmail.com  2024-07-22T15:28:01+03:00
#
#                                                Activite1  \
# 0      Spécialités plurivalentes des échanges et de l...
# 1                                              Autres...
# 2                           Journalisme et communication
# 3                                                  Santé
# 4                  Habillement (y compris mode, couture)
# ...                                                  ...
# 43319                                               None
# 43320                                               None
# 43321                                               None
# 43322                                               None
# 43323                                               None
#
#                                                Activite2  \
# 0      Informatique, traitement de l'information, rés...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 43319                                               None
# 43320                                               None
# 43321                                               None
# 43322                                               None
# 43323                                               None
#
#                      Activite3                   Adresse CodePostale  \
# 0      Enseignement, formation                      None        None
# 1                         None  16 avenue Nelson Mandela       97227
# 2                         None     17 RUE DE BROCELIANDE       35360
# 3                         None             6 RUE FERRERE       33000
# 4                         None                      None        None
# ...                        ...                       ...         ...
# 43319                     None                      None        None
# 43320                     None                      None        None
# 43321                     None                      None        None
# 43322                     None                      None        None
# 43323                     None                      None        None
#
#               Ville           Siret   IDS
# 0              None  38452004500046   140
# 1          STE ANNE  88943425400013   140
# 2      BOISGERVILLY  51202144500014   140
# 3          BORDEAUX  88196598200013   140
# 4              None  52815239000019   140
# ...             ...             ...   ...
# 43319          None            None  None
# 43320          None            None   146
# 43321          None            None   146
# 43322          None            None  None
# 43323          None            None   146
#
# [43324 rows x 14 columns]

# %%
import pandas as pd
import requests
import configparser
from requests_oauthlib import OAuth1
import json
import gspread
from oauth2client.service_account import ServiceAccountCredentials
defaultCrmProspectListUrl = "http://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.userfield.list?ID="

listUrls = []
listeId = []
listID = []
listValuesource = []
listIDd = []

datas = {}

responses = requests.get(defaultCrmProspectListUrl)
        
def testedv():
    if responses.status_code == 200:
        datas = responses.json()
        companyfield = datas['result'][10]['LIST']

        for source in companyfield:
            listID.append(source['ID'])
            listValuesource.append(source['VALUE'])
           
            

            df_btx = pd.DataFrame(list(zip(listID, listValuesource)),
                              columns = ["IDS",'Statut'])

        return df_btx

# %%
dfdd = testedv()
dfdd
# Out:
#    IDS           Statut
# 0  140     Pas Qualiopi
# 1  142         Qualiopi
# 2  144  Qualiopi à jour
# 3  146   Qualiopi perdu

# %%
df_Bitrixyav = dfb.merge(dfdd, how='left')
df_Bitrixyav.drop_duplicates()
df_Bitrixyav.to_csv('companyyavlist.csv', index=False, encoding='utf-8')
df_Bitrixyav
# Out:
#            ID CompanyId                                             nom  \
# 0           4         4                  0CEAN INDIEN INFORMATIQUE SARL
# 1           8         8                                         0'LISTY
# 2          10        10                              1000 ET DEUX IDEES
# 3          12        12         1000 JOURS POUR NAITRE ET GRANDIR EGAUX
# 4          16        16                                    1001 TAILLES
# ...       ...       ...                                             ...
# 43319  157234    157234        ASSOC DEVELOP INFORMAT ADMINISTRAT JURID
# 43320  157236    157236                                   ADH FORMATION
# 43321  157238    157238  ANNE WATKIN L'ATELIER MARQUE PAGE  COACH SCOLA
# 43322  157242    157242                           ATELIERS PETITS DOMES
# 43323  157254    157254                                      Sans titre
#
#                                       Email                       Crée Mobile  \
# 0      contact@0ceanindienifnormatioque.cfr  2023-06-09T10:32:19+03:00
# 1                                            2023-06-09T10:32:19+03:00
# 2                                            2023-06-09T10:32:20+03:00
# 3                                            2023-06-09T10:32:20+03:00
# 4                                            2023-06-09T10:32:20+03:00
# ...                                     ...                        ...    ...
# 43319                                        2024-04-24T18:02:49+03:00
# 43320                                        2024-04-24T18:04:22+03:00
# 43321                                        2024-04-26T12:50:05+03:00
# 43322         atelierspetitsdomes@gmail.com  2024-05-17T18:19:54+03:00
# 43323                  edlotushom@gmail.com  2024-07-22T15:28:01+03:00
#
#                                                Activite1  \
# 0      Spécialités plurivalentes des échanges et de l...
# 1                                              Autres...
# 2                           Journalisme et communication
# 3                                                  Santé
# 4                  Habillement (y compris mode, couture)
# ...                                                  ...
# 43319                                               None
# 43320                                               None
# 43321                                               None
# 43322                                               None
# 43323                                               None
#
#                                                Activite2  \
# 0      Informatique, traitement de l'information, rés...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 43319                                               None
# 43320                                               None
# 43321                                               None
# 43322                                               None
# 43323                                               None
#
#                      Activite3                   Adresse CodePostale  \
# 0      Enseignement, formation                      None        None
# 1                         None  16 avenue Nelson Mandela       97227
# 2                         None     17 RUE DE BROCELIANDE       35360
# 3                         None             6 RUE FERRERE       33000
# 4                         None                      None        None
# ...                        ...                       ...         ...
# 43319                     None                      None        None
# 43320                     None                      None        None
# 43321                     None                      None        None
# 43322                     None                      None        None
# 43323                     None                      None        None
#
#               Ville           Siret   IDS          Statut
# 0              None  38452004500046   140    Pas Qualiopi
# 1          STE ANNE  88943425400013   140    Pas Qualiopi
# 2      BOISGERVILLY  51202144500014   140    Pas Qualiopi
# 3          BORDEAUX  88196598200013   140    Pas Qualiopi
# 4              None  52815239000019   140    Pas Qualiopi
# ...             ...             ...   ...             ...
# 43319          None            None  None             NaN
# 43320          None            None   146  Qualiopi perdu
# 43321          None            None   146  Qualiopi perdu
# 43322          None            None  None             NaN
# 43323          None            None   146  Qualiopi perdu
#
# [43324 rows x 15 columns]

# %%
import pandas as pd

file1_path = 'companyyavlist.csv'
file2_path = 'listesdesqualiopietnon.csv'

try:
    companyyav_df = pd.read_csv(file1_path)
    all_records_export_df = pd.read_csv(file2_path, delimiter=',', on_bad_lines='skip', low_memory=False)
except pd.errors.ParserError as e:
    print(f"Erreur lors de la lecture des fichiers CSV : {e}")

if 'companyyav_df' in locals() and 'all_records_export_df' in locals():
    print("Colonnes disponibles dans 'listesdesqualiopietnon.csv' :")
    print(all_records_export_df.columns)

    if 'siretetablissementdeclarant' in all_records_export_df.columns:
        companyyav_df['Siret'] = companyyav_df['Siret'].astype(str).str.replace(r'\.0$', '', regex=True).str.strip()
        all_records_export_df['siretetablissementdeclarant'] = all_records_export_df['siretetablissementdeclarant'].astype(str).str.strip()

        print(f"Exemples de SIRET dans 'companyyav.csv' : {companyyav_df['Siret'].head()}")
        print(f"Exemples de SIRET dans 'listesdesqualiopietnon.csv' : {all_records_export_df['siretetablissementdeclarant'].head()}")

        unique_siret_companyyav = companyyav_df['Siret'].nunique()
        unique_siret_all_records = all_records_export_df['siretetablissementdeclarant'].nunique()

        print(f"Nombre de SIRET uniques dans 'companyyav.csv': {unique_siret_companyyav}")
        print(f"Nombre de SIRET uniques dans 'listesdesqualiopietnon.csv': {unique_siret_all_records}")

        common_values = companyyav_df[companyyav_df['Siret'].isin(all_records_export_df['siretetablissementdeclarant'])]
        print(f"Nombre de correspondances trouvées: {common_values.shape[0]}")

        merged_df = pd.merge(common_values, all_records_export_df, left_on='Siret', right_on='siretetablissementdeclarant')

        print("\nInformations des valeurs communes dans 'Siret' et 'siretetablissementdeclarant':")
        print(merged_df.head()) 

        missing_siret_in_all_records = companyyav_df[~companyyav_df['Siret'].isin(all_records_export_df['siretetablissementdeclarant'])]
        print(f"Nombre de SIRET dans 'companyyav.csv' non trouvés dans 'listesdesqualiopietnon.csv': {missing_siret_in_all_records.shape[0]}")
        print(missing_siret_in_all_records.head())
    else:
        print("La colonne 'siretetablissementdeclarant' n'existe pas dans le fichier 'listesdesqualiopietnon.csv'.")
else:
    print("Les fichiers n'ont pas pu être chargés correctement.")
# Out:
# Colonnes disponibles dans 'listesdesqualiopietnon.csv' :
# Index(['numerodeclarationactivite', 'numerosdeclarationactiviteprecedent',
#        'denomination', 'siren', 'siretetablissementdeclarant',
#        'adressephysiqueorganismeformation_voie',
#        'adressephysiqueorganismeformation_codepostal',
#        'adressephysiqueorganismeformation_ville',
#        'adressephysiqueorganismeformation_coderegion', 'geocodageban',
#        'certifications_actionsdeformation',
#        'certifications_bilansdecompetences', 'certifications_vae',
#        'certifications_actionsdeformationparapprentissage',
#        'organismeetrangerrepresente_denomination',
#        'organismeetrangerrepresente_voie',
#        'organismeetrangerrepresente_codepostal',
#        'organismeetrangerrepresente_ville', 'organismeetrangerrepresente_pays',
#        'informationsdeclarees_datedernieredeclaration',
#        'informationsdeclarees_debutexercice',
#        'informationsdeclarees_finexercice',
#        'informationsdeclarees_specialitesdeformation_codespecialite1',
#        'informationsdeclarees_specialitesdeformation_libellespecialite1',
#        'informationsdeclarees_specialitesdeformation_codespecialite2',
#        'informationsdeclarees_specialitesdeformation_libellespecialite2',
#        'informationsdeclarees_specialitesdeformation_codespecialite3',
#        'informationsdeclarees_specialitesdeformation_libellespecialite3',
#        'informationsdeclarees_nbstagiaires',
#        'informationsdeclarees_nbstagiairesconfiesparunautreof',
#        'informationsdeclarees_effectifformateurs', 'com_arm_code',
#        'com_arm_name', 'epci_code', 'epci_name', 'dep_code', 'dep_name',
#        'reg_name', 'reg_code', 'toutes_specialites',
#        'organisme_formation_geocode', 'certifications', 'random_id'],
#       dtype='object')
# Exemples de SIRET dans 'companyyav.csv' : 0    38452004500046
# 1    88943425400013
# 2    51202144500014
# 3    88196598200013
# 4    52815239000019
# Name: Siret, dtype: object
# Exemples de SIRET dans 'listesdesqualiopietnon.csv' : 0    89017665400014
# 1    33506030700063
# 2    89461217500014
# 3    80188068300025
# 4    82164621300024
# Name: siretetablissementdeclarant, dtype: object
# Nombre de SIRET uniques dans 'companyyav.csv': 42265
# Nombre de SIRET uniques dans 'listesdesqualiopietnon.csv': 134382
# Nombre de correspondances trouvées: 41804
#
# Informations des valeurs communes dans 'Siret' et 'siretetablissementdeclarant':
#    ID  CompanyId                                      nom  \
# 0   4          4           0CEAN INDIEN INFORMATIQUE SARL
# 1   8          8                                  0'LISTY
# 2  10         10                       1000 ET DEUX IDEES
# 3  12         12  1000 JOURS POUR NAITRE ET GRANDIR EGAUX
# 4  16         16                             1001 TAILLES
#
#                                   Email                       Crée  Mobile  \
# 0  contact@0ceanindienifnormatioque.cfr  2023-06-09T10:32:19+03:00     NaN
# 1                                   NaN  2023-06-09T10:32:19+03:00     NaN
# 2                                   NaN  2023-06-09T10:32:20+03:00     NaN
# 3                                   NaN  2023-06-09T10:32:20+03:00     NaN
# 4                                   NaN  2023-06-09T10:32:20+03:00     NaN
#
#                                            Activite1  \
# 0  Spécialités plurivalentes des échanges et de l...
# 1                                          Autres...
# 2                       Journalisme et communication
# 3                                              Santé
# 4              Habillement (y compris mode, couture)
#
#                                            Activite2                Activite3  \
# 0  Informatique, traitement de l'information, rés...  Enseignement, formation
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#                     Adresse  ...    epci_code  \
# 0                       NaN  ...          NaN
# 1  16 avenue Nelson Mandela  ...  249720053.0
# 2     17 RUE DE BROCELIANDE  ...  200038990.0
# 3             6 RUE FERRERE  ...  243300316.0
# 4                       NaN  ...          NaN
#
#                                            epci_name dep_code  \
# 0                                                NaN      NaN
# 1  Communauté d'agglomération de l'Espace Sud de ...      972
# 2     Communauté de communes de Saint-Méen Montauban       35
# 3                                 Bordeaux Métropole       33
# 4                                                NaN      NaN
#
#             dep_name            reg_name reg_code  \
# 0  Pas de départment          La Réunion        4
# 1         Martinique          Martinique        2
# 2    Ille-et-Vilaine            Bretagne       53
# 3            Gironde  Nouvelle-Aquitaine       75
# 4  Pas de départment           Grand Est       44
#
#                                   toutes_specialites  \
# 0  Spécialités plurivalentes des échanges et de l...
# 1                                                NaN
# 2                       Journalisme et communication
# 3                                              Santé
# 4              Habillement (y compris mode, couture)
#
#   organisme_formation_geocode  certifications  random_id
# 0                       False             NaN  12.453197
# 1                        True             NaN  47.909540
# 2                        True             NaN  99.751729
# 3                        True             NaN  54.842549
# 4                       False             NaN  58.783796
#
# [5 rows x 58 columns]
# Nombre de SIRET dans 'companyyav.csv' non trouvés dans 'listesdesqualiopietnon.csv': 1520
#        ID  CompanyId                                               nom Email  \
# 206   760        760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN   NaN
# 283   968        968                             ABConsultant & Net Oi   NaN
# 326  1094       1094                                      AB FORMATION   NaN
# 500  1568       1568                                            ACCEVA   NaN
# 506  1584       1584                        ACCIOR LES SABLES D'OLONNE   NaN
#
#                           Crée  Mobile              Activite1  \
# 206  2023-06-09T10:32:45+03:00     NaN   Formations générales
# 283  2023-06-09T10:32:53+03:00     NaN        Commerce, vente
# 326  2023-06-09T10:32:58+03:00     NaN  Comptabilité, gestion
# 500  2023-06-09T10:33:18+03:00     NaN         Travail social
# 506  2023-06-09T10:33:18+03:00     NaN  Comptabilité, gestion
#
#                                              Activite2 Activite3  \
# 206                                          Autres...       NaN
# 283  Ressources humaines, gestion du personnel, ges...       NaN
# 326                                                NaN       NaN
# 500                            Enseignement, formation       NaN
# 506  Ressources humaines, gestion du personnel, ges...       NaN
#
#                           Adresse  CodePostale    Ville           Siret  \
# 206         29 RUE ROMAIN ROLLAND      44100.0   NANTES  50316997100010
# 283                           NaN          NaN      NaN  85297199300021
# 326  27 CHEMIN DE LA CAVERNE N°17      97434.0  ST PAUL  52340659300021
# 500                           NaN          NaN      NaN  84931718500015
# 506                           NaN          NaN      NaN  32890745600029
#
#        IDS        Statut
# 206  140.0  Pas Qualiopi
# 283  140.0  Pas Qualiopi
# 326  140.0  Pas Qualiopi
# 500  140.0  Pas Qualiopi
# 506  140.0  Pas Qualiopi

# %%
merged_df.to_csv("Liste_des_dgefp_qui_existe_dans_bitrix_et_dans_la_liste_des_dgefp.csv", index=False)
merged_df
# Out:
#            ID  CompanyId                                      nom  \
# 0           4          4           0CEAN INDIEN INFORMATIQUE SARL
# 1           8          8                                  0'LISTY
# 2          10         10                       1000 ET DEUX IDEES
# 3          12         12  1000 JOURS POUR NAITRE ET GRANDIR EGAUX
# 4          16         16                             1001 TAILLES
# ...       ...        ...                                      ...
# 41810  131308     131308                    PROFIL SUD MANAGEMENT
# 41811  131310     131310                                  PROFIND
# 41812  143788     143788                                 SOLURISK
# 41813  153216     153216                          WAYUP INSTITUTE
# 41814  154108     154108                                   XTREMA
#
#                                       Email                       Crée  \
# 0      contact@0ceanindienifnormatioque.cfr  2023-06-09T10:32:19+03:00
# 1                                       NaN  2023-06-09T10:32:19+03:00
# 2                                       NaN  2023-06-09T10:32:20+03:00
# 3                                       NaN  2023-06-09T10:32:20+03:00
# 4                                       NaN  2023-06-09T10:32:20+03:00
# ...                                     ...                        ...
# 41810                                   NaN  2023-06-09T17:20:54+03:00
# 41811                                   NaN  2023-06-09T17:20:54+03:00
# 41812                  contact@solurisk.com  2023-06-09T17:42:12+03:00
# 41813      pascal.jacob@wayup-institute.com  2023-06-09T17:47:56+03:00
# 41814                      josick@xtrema.fr  2023-06-09T17:48:28+03:00
#
#        Mobile                                          Activite1  \
# 0         NaN  Spécialités plurivalentes des échanges et de l...
# 1         NaN                                          Autres...
# 2         NaN                       Journalisme et communication
# 3         NaN                                              Santé
# 4         NaN              Habillement (y compris mode, couture)
# ...       ...                                                ...
# 41810     NaN  Ressources humaines, gestion du personnel, ges...
# 41811     NaN  Informatique, traitement de l'information, rés...
# 41812     NaN  Spécialités pluridisciplinaires, sciences huma...
# 41813     NaN                           Secrétariat, bureautique
# 41814     NaN  Développement des capacités comportementales e...
#
#                                                Activite2  \
# 0      Informatique, traitement de l'information, rés...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 41810  Développement des capacités comportementales e...
# 41811                                                NaN
# 41812  Sécurité des biens et des personnes, police, s...
# 41813  Informatique, traitement de l'information, rés...
# 41814                                                NaN
#
#                      Activite3                   Adresse  ...    epci_code  \
# 0      Enseignement, formation                       NaN  ...          NaN
# 1                          NaN  16 avenue Nelson Mandela  ...  249720053.0
# 2                          NaN     17 RUE DE BROCELIANDE  ...  200038990.0
# 3                          NaN             6 RUE FERRERE  ...  243300316.0
# 4                          NaN                       NaN  ...          NaN
# ...                        ...                       ...  ...          ...
# 41810                      NaN                       NaN  ...          NaN
# 41811                      NaN    17-21 RUE SAINT-FIACRE  ...  200054781.0
# 41812                      NaN      379 RUE DE MACQUIGNY  ...  200071983.0
# 41813                      NaN                       NaN  ...          NaN
# 41814                      NaN                       NaN  ...          NaN
#
#                                                epci_name dep_code  \
# 0                                                    NaN      NaN
# 1      Communauté d'agglomération de l'Espace Sud de ...      972
# 2         Communauté de communes de Saint-Méen Montauban       35
# 3                                     Bordeaux Métropole       33
# 4                                                    NaN      NaN
# ...                                                  ...      ...
# 41810                                                NaN      NaN
# 41811                           Métropole du Grand Paris       75
# 41812    Communauté de communes Thiérache Sambre et Oise       02
# 41813                                                NaN      NaN
# 41814                                                NaN      NaN
#
#                 dep_name                    reg_name reg_code  \
# 0      Pas de départment                  La Réunion        4
# 1             Martinique                  Martinique        2
# 2        Ille-et-Vilaine                    Bretagne       53
# 3                Gironde          Nouvelle-Aquitaine       75
# 4      Pas de départment                   Grand Est       44
# ...                  ...                         ...      ...
# 41810  Pas de départment  Provence-Alpes-Côte d'Azur       93
# 41811              Paris               Île-de-France       11
# 41812              Aisne             Hauts-de-France       32
# 41813  Pas de départment               Île-de-France       11
# 41814  Pas de départment                   Normandie       28
#
#                                       toutes_specialites  \
# 0      Spécialités plurivalentes des échanges et de l...
# 1                                                    NaN
# 2                           Journalisme et communication
# 3                                                  Santé
# 4                  Habillement (y compris mode, couture)
# ...                                                  ...
# 41810  Ressources humaines, gestion du personnel, ges...
# 41811  Informatique, traitement de l'information, rés...
# 41812  Sécurité des biens et des personnes, police, s...
# 41813  Informatique, traitement de l'information, rés...
# 41814  Développement des capacités comportementales e...
#
#       organisme_formation_geocode  certifications  random_id
# 0                           False             NaN  12.453197
# 1                            True             NaN  47.909540
# 2                            True             NaN  99.751729
# 3                            True             NaN  54.842549
# 4                           False             NaN  58.783796
# ...                           ...             ...        ...
# 41810                       False             NaN  87.519574
# 41811                        True             NaN  30.701510
# 41812                        True             NaN  92.769546
# 41813                       False             NaN  67.692930
# 41814                       False             NaN   8.485809
#
# [41815 rows x 58 columns]

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;">Je vérifie si les entreprises YAV conservent leur statut Qualiopi dans DFFEP (indiquant un changement de statut).</span>

# %%
import pandas as pd

df_dgefp = pd.read_csv('Liste_des_dgefp_qui_existe_dans_bitrix_et_dans_la_liste_des_dgefp.csv')
df_qualiopi = pd.read_csv('listesdesqualiopietnon.csv')

print("Échantillon des valeurs dans la colonne 'Siret' du premier CSV :")
print(df_dgefp['Siret'].head())

print("\nÉchantillon des valeurs dans la colonne 'siretetablissementdeclarant' du deuxième CSV :")
print(df_qualiopi['siretetablissementdeclarant'].head())

print("\nType de la colonne 'Siret' : ", df_dgefp['Siret'].dtype)
print("Type de la colonne 'siretetablissementdeclarant' : ", df_qualiopi['siretetablissementdeclarant'].dtype)

df_dgefp['Siret'] = df_dgefp['Siret'].astype(str).str.strip()
df_qualiopi['siretetablissementdeclarant'] = df_qualiopi['siretetablissementdeclarant'].astype(str).str.strip()

print("\nAprès conversion si nécessaire :")
print(df_dgefp['Siret'].head())
print(df_qualiopi['siretetablissementdeclarant'].head())
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13304\2362527447.py:3: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dgefp = pd.read_csv('Liste_des_dgefp_qui_existe_dans_bitrix_et_dans_la_liste_des_dgefp.csv')
# C:\Users\PC\AppData\Local\Temp\ipykernel_13304\2362527447.py:4: DtypeWarning: Columns (0,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_qualiopi = pd.read_csv('listesdesqualiopietnon.csv')
# Échantillon des valeurs dans la colonne 'Siret' du premier CSV :
# 0    38452004500046
# 1    88943425400013
# 2    51202144500014
# 3    88196598200013
# 4    52815239000019
# Name: Siret, dtype: int64
#
# Échantillon des valeurs dans la colonne 'siretetablissementdeclarant' du deuxième CSV :
# 0    89017665400014
# 1    33506030700063
# 2    89461217500014
# 3    80188068300025
# 4    82164621300024
# Name: siretetablissementdeclarant, dtype: int64
#
# Type de la colonne 'Siret' :  int64
# Type de la colonne 'siretetablissementdeclarant' :  int64
#
# Après conversion si nécessaire :
# 0    38452004500046
# 1    88943425400013
# 2    51202144500014
# 3    88196598200013
# 4    52815239000019
# Name: Siret, dtype: object
# 0    89017665400014
# 1    33506030700063
# 2    89461217500014
# 3    80188068300025
# 4    82164621300024
# Name: siretetablissementdeclarant, dtype: object

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;">Récuperation des non qualiopi DGEFP.</span>

# %%
import pandas as pd

df = pd.read_csv("listesdesqualiopietnon.csv", encoding='utf-8', low_memory=False)

colonnes_a_verifier = [
    'certifications_actionsdeformation', 
    'certifications_bilansdecompetences', 
    'certifications_vae', 
    'certifications_actionsdeformationparapprentissage'
]

df_nan = df[colonnes_a_verifier].isna()

df_nan_info = df[df_nan.any(axis=1)]

df_nan_info.to_csv("Liste_non_qualiopi_DGEFP.csv", index=False)
df_nan_info
# Out:
#        numerodeclarationactivite numerosdeclarationactiviteprecedent  \
# 2                    11922694992                         11922694992
# 3                    93061133106                         93061133106
# 5                    32800243480                         32800243480
# 6                    98970223197                         98970223197
# 7                    52490410349                         52490410349
# ...                          ...                                 ...
# 134402               11753254275                         11753254275
# 134403               28760673976             75331298733,28760673976
# 134405               41570304557             11930118993,41570304557
# 134406               11788581278                         11788581278
# 134407               11755090675                         11755090675
#
#                                          denomination      siren  \
# 2                                       01 CQFD AUDIT  894612175
# 3                                              01MARS  801880683
# 5                                               07H01  952975084
# 6                      0CEAN INDIEN INFORMATIQUE SARL  384520045
# 7                                            0FC.TECH  917429516
# ...                                               ...        ...
# 134402  ZUNINO NAUDEAU BENEDICTE (CAROBELL FORMATION)  400838975
# 134403                             ZVENIGOROSKY IRENE  832033559
# 134405                                     ZWICKROELL  315547927
# 134406                                          ZYBRA  878152065
# 134407                                     Z. YOUAKIM  539019943
#
#         siretetablissementdeclarant   adressephysiqueorganismeformation_voie  \
# 2                    89461217500014                     33  RUE ANNA JACQUIN
# 3                    80188068300025                  84  RUE MARECHAL JOFFRE
# 5                    95297508400015                    6  PLACE D’HEDOUVILLE
# 6                    38452004500046                                      NaN
# 7                    91742951600029              8  PLACE MONSEIGNEUR RUMEAU
# ...                             ...                                      ...
# 134402               40083897500029                                      NaN
# 134403               83203355900036                   140 ALLÉE DES BUISSONS
# 134405               31554792700063  4 Rue Royal Canadian Air Force CS 45191
# 134406               87815206500016                      3 CHE DES CARRIERES
# 134407               53901994300031                                      NaN
#
#         adressephysiqueorganismeformation_codepostal  \
# 2                                            92100.0
# 3                                             6000.0
# 5                                            80300.0
# 6                                                NaN
# 7                                            49100.0
# ...                                              ...
# 134402                                           NaN
# 134403                                       76160.0
# 134405                                       57075.0
# 134406                                       78540.0
# 134407                                           NaN
#
#        adressephysiqueorganismeformation_ville  \
# 2                         BOULOGNE BILLANCOURT
# 3                                         NICE
# 5                                       ALBERT
# 6                                          NaN
# 7                                       ANGERS
# ...                                        ...
# 134402                                     NaN
# 134403                                  PREAUX
# 134405                           ARS LAQUENEXY
# 134406                             VERNOUILLET
# 134407                                     NaN
#
#         adressephysiqueorganismeformation_coderegion          geocodageban  \
# 2                                                 11   48.844944, 2.228016
# 3                                                 93   43.697144, 7.257563
# 5                                                 32    50.006122, 2.65106
# 6                                                  4                   NaN
# 7                                                 52  47.468597, -0.562892
# ...                                              ...                   ...
# 134402                                            11                   NaN
# 134403                                            28   49.487453, 1.215396
# 134405                                            44                   NaN
# 134406                                            11   48.967265, 1.985073
# 134407                                            11                   NaN
#
#         ...    epci_code                                     epci_name  \
# 2       ...  200054781.0                      Métropole du Grand Paris
# 3       ...  200030195.0                    Métropole Nice Côte d'Azur
# 5       ...  248000747.0  Communauté de communes du Pays du Coquelicot
# 6       ...          NaN                                           NaN
# 7       ...  244900015.0     Communauté urbaine Angers Loire Métropole
# ...     ...          ...                                           ...
# 134402  ...          NaN                                           NaN
# 134403  ...  200070449.0       Communauté de communes Inter-Caux-Vexin
# 134405  ...          NaN                                           NaN
# 134406  ...  200059889.0  Communauté urbaine Grand Paris Seine et Oise
# 134407  ...          NaN                                           NaN
#
#        dep_code           dep_name                    reg_name reg_code  \
# 2            92     Hauts-de-Seine               Île-de-France       11
# 3            06    Alpes-Maritimes  Provence-Alpes-Côte d'Azur       93
# 5            80              Somme             Hauts-de-France       32
# 6           NaN  Pas de départment                  La Réunion        4
# 7            49     Maine-et-Loire            Pays de la Loire       52
# ...         ...                ...                         ...      ...
# 134402      NaN  Pas de départment               Île-de-France       11
# 134403       76     Seine-Maritime                   Normandie       28
# 134405      NaN  Pas de départment                   Grand Est       44
# 134406       78           Yvelines               Île-de-France       11
# 134407      NaN  Pas de départment               Île-de-France       11
#
#                                        toutes_specialites  \
# 2                                   Comptabilité, gestion
# 3           Spécialités plurivalentes de la communication
# 5        Spécialités plurivalentes des services,Autres...
# 6       Spécialités plurivalentes des échanges et de l...
# 7       Informatique, traitement de l'information, rés...
# ...                                                   ...
# 134402  Développement des capacités comportementales e...
# 134403                                              Santé
# 134405  Métallurgie (y compris sidérurgie, fonderie, n...
# 134406                            Enseignement, formation
# 134407  Développement des capacités comportementales e...
#
#        organisme_formation_geocode certifications  random_id
# 2                             True            NaN  12.214291
# 3                             True            NaN  79.460767
# 5                             True            NaN  18.847509
# 6                            False            NaN  12.453197
# 7                             True            NaN  69.263306
# ...                            ...            ...        ...
# 134402                       False            NaN  59.067962
# 134403                        True            NaN  68.394827
# 134405                       False            NaN  13.087755
# 134406                        True            NaN  97.731259
# 134407                       False            NaN  39.436185
#
# [89810 rows x 43 columns]

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;">Récuperation des Non qualiopi YAV.</span>

# %%
import pandas as pd

df_dgefp = pd.read_csv('companyyavlist.csv')

df_dgefp['Siret'] = df_dgefp['Siret'].apply(lambda x: '{:.0f}'.format(x))

df_pas_qualiopi = df_dgefp[df_dgefp['Statut'] == 'Pas Qualiopi']

if not df_pas_qualiopi.empty:
    print("Entreprises avec le statut 'Pas Qualiopi':")
    print(df_pas_qualiopi)
else:
    print("Aucune entreprise avec le statut 'Pas Qualiopi' n'a été trouvée.")
# Out:
# Entreprises avec le statut 'Pas Qualiopi':
#            ID  CompanyId                                      nom  \
# 0           4          4           0CEAN INDIEN INFORMATIQUE SARL
# 1           8          8                                  0'LISTY
# 2          10         10                       1000 ET DEUX IDEES
# 3          12         12  1000 JOURS POUR NAITRE ET GRANDIR EGAUX
# 4          16         16                             1001 TAILLES
# ...       ...        ...                                      ...
# 42261  131308     131308                    PROFIL SUD MANAGEMENT
# 42262  131310     131310                                  PROFIND
# 42263  143788     143788                                 SOLURISK
# 42265  153216     153216                          WAYUP INSTITUTE
# 42266  154108     154108                                   XTREMA
#
#                                       Email                       Crée  \
# 0      contact@0ceanindienifnormatioque.cfr  2023-06-09T10:32:19+03:00
# 1                                       NaN  2023-06-09T10:32:19+03:00
# 2                                       NaN  2023-06-09T10:32:20+03:00
# 3                                       NaN  2023-06-09T10:32:20+03:00
# 4                                       NaN  2023-06-09T10:32:20+03:00
# ...                                     ...                        ...
# 42261                                   NaN  2023-06-09T17:20:54+03:00
# 42262                                   NaN  2023-06-09T17:20:54+03:00
# 42263                  contact@solurisk.com  2023-06-09T17:42:12+03:00
# 42265      pascal.jacob@wayup-institute.com  2023-06-09T17:47:56+03:00
# 42266                      josick@xtrema.fr  2023-06-09T17:48:28+03:00
#
#        Mobile                                          Activite1  \
# 0         NaN  Spécialités plurivalentes des échanges et de l...
# 1         NaN                                          Autres...
# 2         NaN                       Journalisme et communication
# 3         NaN                                              Santé
# 4         NaN              Habillement (y compris mode, couture)
# ...       ...                                                ...
# 42261     NaN  Ressources humaines, gestion du personnel, ges...
# 42262     NaN  Informatique, traitement de l'information, rés...
# 42263     NaN  Spécialités pluridisciplinaires, sciences huma...
# 42265     NaN                           Secrétariat, bureautique
# 42266     NaN  Développement des capacités comportementales e...
#
#                                                Activite2  \
# 0      Informatique, traitement de l'information, rés...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 42261  Développement des capacités comportementales e...
# 42262                                                NaN
# 42263  Sécurité des biens et des personnes, police, s...
# 42265  Informatique, traitement de l'information, rés...
# 42266                                                NaN
#
#                      Activite3                   Adresse  CodePostale  \
# 0      Enseignement, formation                       NaN          NaN
# 1                          NaN  16 avenue Nelson Mandela      97227.0
# 2                          NaN     17 RUE DE BROCELIANDE      35360.0
# 3                          NaN             6 RUE FERRERE      33000.0
# 4                          NaN                       NaN          NaN
# ...                        ...                       ...          ...
# 42261                      NaN                       NaN          NaN
# 42262                      NaN    17-21 RUE SAINT-FIACRE      75002.0
# 42263                      NaN      379 RUE DE MACQUIGNY       2120.0
# 42265                      NaN                       NaN          NaN
# 42266                      NaN                       NaN          NaN
#
#               Ville           Siret    IDS        Statut
# 0               NaN  38452004500046  140.0  Pas Qualiopi
# 1          STE ANNE  88943425400013  140.0  Pas Qualiopi
# 2      BOISGERVILLY  51202144500014  140.0  Pas Qualiopi
# 3          BORDEAUX  88196598200013  140.0  Pas Qualiopi
# 4               NaN  52815239000019  140.0  Pas Qualiopi
# ...             ...             ...    ...           ...
# 42261           NaN  45125191200064  140.0  Pas Qualiopi
# 42262      PARIS 02  52370160500041  140.0  Pas Qualiopi
# 42263         GUISE  89335239300019  140.0  Pas Qualiopi
# 42265           NaN  52900201600010  140.0  Pas Qualiopi
# 42266           NaN  38970709200034  140.0  Pas Qualiopi
#
# [39318 rows x 15 columns]

# %%
df_pas_qualiopi.to_csv("Liste_Pas_qualiopi_YAV.csv", index=False)
df_pas_qualiopi
# Out:
#            ID  CompanyId                                      nom  \
# 0           4          4           0CEAN INDIEN INFORMATIQUE SARL
# 1           8          8                                  0'LISTY
# 2          10         10                       1000 ET DEUX IDEES
# 3          12         12  1000 JOURS POUR NAITRE ET GRANDIR EGAUX
# 4          16         16                             1001 TAILLES
# ...       ...        ...                                      ...
# 42261  131308     131308                    PROFIL SUD MANAGEMENT
# 42262  131310     131310                                  PROFIND
# 42263  143788     143788                                 SOLURISK
# 42265  153216     153216                          WAYUP INSTITUTE
# 42266  154108     154108                                   XTREMA
#
#                                       Email                       Crée  \
# 0      contact@0ceanindienifnormatioque.cfr  2023-06-09T10:32:19+03:00
# 1                                       NaN  2023-06-09T10:32:19+03:00
# 2                                       NaN  2023-06-09T10:32:20+03:00
# 3                                       NaN  2023-06-09T10:32:20+03:00
# 4                                       NaN  2023-06-09T10:32:20+03:00
# ...                                     ...                        ...
# 42261                                   NaN  2023-06-09T17:20:54+03:00
# 42262                                   NaN  2023-06-09T17:20:54+03:00
# 42263                  contact@solurisk.com  2023-06-09T17:42:12+03:00
# 42265      pascal.jacob@wayup-institute.com  2023-06-09T17:47:56+03:00
# 42266                      josick@xtrema.fr  2023-06-09T17:48:28+03:00
#
#        Mobile                                          Activite1  \
# 0         NaN  Spécialités plurivalentes des échanges et de l...
# 1         NaN                                          Autres...
# 2         NaN                       Journalisme et communication
# 3         NaN                                              Santé
# 4         NaN              Habillement (y compris mode, couture)
# ...       ...                                                ...
# 42261     NaN  Ressources humaines, gestion du personnel, ges...
# 42262     NaN  Informatique, traitement de l'information, rés...
# 42263     NaN  Spécialités pluridisciplinaires, sciences huma...
# 42265     NaN                           Secrétariat, bureautique
# 42266     NaN  Développement des capacités comportementales e...
#
#                                                Activite2  \
# 0      Informatique, traitement de l'information, rés...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 42261  Développement des capacités comportementales e...
# 42262                                                NaN
# 42263  Sécurité des biens et des personnes, police, s...
# 42265  Informatique, traitement de l'information, rés...
# 42266                                                NaN
#
#                      Activite3                   Adresse  CodePostale  \
# 0      Enseignement, formation                       NaN          NaN
# 1                          NaN  16 avenue Nelson Mandela      97227.0
# 2                          NaN     17 RUE DE BROCELIANDE      35360.0
# 3                          NaN             6 RUE FERRERE      33000.0
# 4                          NaN                       NaN          NaN
# ...                        ...                       ...          ...
# 42261                      NaN                       NaN          NaN
# 42262                      NaN    17-21 RUE SAINT-FIACRE      75002.0
# 42263                      NaN      379 RUE DE MACQUIGNY       2120.0
# 42265                      NaN                       NaN          NaN
# 42266                      NaN                       NaN          NaN
#
#               Ville           Siret    IDS        Statut
# 0               NaN  38452004500046  140.0  Pas Qualiopi
# 1          STE ANNE  88943425400013  140.0  Pas Qualiopi
# 2      BOISGERVILLY  51202144500014  140.0  Pas Qualiopi
# 3          BORDEAUX  88196598200013  140.0  Pas Qualiopi
# 4               NaN  52815239000019  140.0  Pas Qualiopi
# ...             ...             ...    ...           ...
# 42261           NaN  45125191200064  140.0  Pas Qualiopi
# 42262      PARIS 02  52370160500041  140.0  Pas Qualiopi
# 42263         GUISE  89335239300019  140.0  Pas Qualiopi
# 42265           NaN  52900201600010  140.0  Pas Qualiopi
# 42266           NaN  38970709200034  140.0  Pas Qualiopi
#
# [39318 rows x 15 columns]

# %%
import pandas as pd

df_pas_qualiopi_yav = pd.read_csv('Liste_Pas_qualiopi_YAV.csv')
df_non_qualiopi = pd.read_csv('Liste_non_qualiopi_DGEFP.csv')
df_pas_qualiopi_yav['Siret'] = df_pas_qualiopi_yav['Siret'].apply(lambda x: '{:.0f}'.format(x))
df_non_qualiopi['siretetablissementdeclarant'] = df_non_qualiopi['siretetablissementdeclarant'].apply(lambda x: '{:.0f}'.format(x))
df_non_matching = df_pas_qualiopi_yav[~df_pas_qualiopi_yav['Siret'].isin(df_non_qualiopi['siretetablissementdeclarant'])]

if not df_non_matching.empty:
    print("Les entreprises dont les 'Siret' de Liste_Pas_qualiopi_YAV ne se trouvent PAS dans Liste_non_qualiopi_DGEFP :")
    print(df_non_matching)
else:
    print("Toutes les entreprises de Liste_Pas_qualiopi_YAV ont un 'Siret' correspondant dans Liste_non_qualiopi_DGEFP.")
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13304\2550940162.py:4: DtypeWarning: Columns (0,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_non_qualiopi = pd.read_csv('Liste_non_qualiopi_DGEFP.csv')
# Les entreprises dont les 'Siret' de Liste_Pas_qualiopi_YAV ne se trouvent PAS dans Liste_non_qualiopi_DGEFP :
#            ID  CompanyId                                               nom  \
# 169       702        702                                               A2O
# 187       760        760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN
# 260       968        968                             ABConsultant & Net Oi
# 301      1094       1094                                      AB FORMATION
# 449      1568       1568                                            ACCEVA
# ...       ...        ...                                               ...
# 38608  129254     129254                                  PICANTIN Olivier
# 38709  129514     129514                   PIERSON DOMINIQUE (DP TRAINING)
# 38869  129972     129972                                PLUMES DE CIGOGNES
# 38892  130040     130040                                    PMO SUSTAINING
# 39263  131138     131138                                 PRO ARTE GRAPHICA
#
#       Email                       Crée  Mobile  \
# 169     NaN  2023-06-09T10:32:42+03:00     NaN
# 187     NaN  2023-06-09T10:32:45+03:00     NaN
# 260     NaN  2023-06-09T10:32:53+03:00     NaN
# 301     NaN  2023-06-09T10:32:58+03:00     NaN
# 449     NaN  2023-06-09T10:33:18+03:00     NaN
# ...     ...                        ...     ...
# 38608   NaN  2023-06-09T17:19:45+03:00     NaN
# 38709   NaN  2023-06-09T17:19:53+03:00     NaN
# 38869   NaN  2023-06-09T17:20:09+03:00     NaN
# 38892   NaN  2023-06-09T17:20:12+03:00     NaN
# 39263   NaN  2023-06-09T17:20:49+03:00     NaN
#
#                                                Activite1  \
# 169    Développement des capacités d'orientation, d'i...
# 187                                 Formations générales
# 260                                      Commerce, vente
# 301                                Comptabilité, gestion
# 449                                       Travail social
# ...                                                  ...
# 38608                                                NaN
# 38709                               Formations générales
# 38869               Bâtiment: construction et couverture
# 38892           Technologies industrielles fondamentales
# 39263  Autres disciplines artistiques et spécialités ...
#
#                                                Activite2  \
# 169                                                  NaN
# 187                                            Autres...
# 260    Ressources humaines, gestion du personnel, ges...
# 301                                                  NaN
# 449                              Enseignement, formation
# ...                                                  ...
# 38608                                                NaN
# 38709                                    Commerce, vente
# 38869  Sécurité des biens et des personnes, police, s...
# 38892                                                NaN
# 39263         Techniques de l'imprimerie et de l'édition
#
#                    Activite3                       Adresse  CodePostale  \
# 169                      NaN               140 RUE DE LORS      87380.0
# 187                      NaN         29 RUE ROMAIN ROLLAND      44100.0
# 260                      NaN                           NaN          NaN
# 301                      NaN  27 CHEMIN DE LA CAVERNE N°17      97434.0
# 449                      NaN                           NaN          NaN
# ...                      ...                           ...          ...
# 38608                    NaN                           NaN          NaN
# 38709  Comptabilité, gestion                   36 RUE CLER      75007.0
# 38869                    NaN           10 RUE DES CIGOGNES      97480.0
# 38892                    NaN            1 CHEMIN DE L'ONDE      44240.0
# 39263                    NaN          24, quai de la Fosse      44000.0
#
#                        Ville           Siret    IDS        Statut
# 169                  GLANGES  81063315600015  140.0  Pas Qualiopi
# 187                   NANTES  50316997100010  140.0  Pas Qualiopi
# 260                      NaN  85297199300021  140.0  Pas Qualiopi
# 301                  ST PAUL  52340659300021  140.0  Pas Qualiopi
# 449                      NaN  84931718500015  140.0  Pas Qualiopi
# ...                      ...             ...    ...           ...
# 38608                    NaN  85205528400016  140.0  Pas Qualiopi
# 38709               PARIS 07  44922655400060  140.0  Pas Qualiopi
# 38869              ST JOSEPH  91812767100017  140.0  Pas Qualiopi
# 38892  LA CHAPELLE SUR ERDRE  52338497200023  140.0  Pas Qualiopi
# 39263                 NANTES  33864179800016  140.0  Pas Qualiopi
#
# [473 rows x 15 columns]

# %%
df_non_matching.to_csv('Non_Matching_Siret_YAV_Results.csv', index=False)
df_non_matching
# Out:
#            ID  CompanyId                                               nom  \
# 169       702        702                                               A2O
# 187       760        760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN
# 260       968        968                             ABConsultant & Net Oi
# 301      1094       1094                                      AB FORMATION
# 449      1568       1568                                            ACCEVA
# ...       ...        ...                                               ...
# 38608  129254     129254                                  PICANTIN Olivier
# 38709  129514     129514                   PIERSON DOMINIQUE (DP TRAINING)
# 38869  129972     129972                                PLUMES DE CIGOGNES
# 38892  130040     130040                                    PMO SUSTAINING
# 39263  131138     131138                                 PRO ARTE GRAPHICA
#
#       Email                       Crée  Mobile  \
# 169     NaN  2023-06-09T10:32:42+03:00     NaN
# 187     NaN  2023-06-09T10:32:45+03:00     NaN
# 260     NaN  2023-06-09T10:32:53+03:00     NaN
# 301     NaN  2023-06-09T10:32:58+03:00     NaN
# 449     NaN  2023-06-09T10:33:18+03:00     NaN
# ...     ...                        ...     ...
# 38608   NaN  2023-06-09T17:19:45+03:00     NaN
# 38709   NaN  2023-06-09T17:19:53+03:00     NaN
# 38869   NaN  2023-06-09T17:20:09+03:00     NaN
# 38892   NaN  2023-06-09T17:20:12+03:00     NaN
# 39263   NaN  2023-06-09T17:20:49+03:00     NaN
#
#                                                Activite1  \
# 169    Développement des capacités d'orientation, d'i...
# 187                                 Formations générales
# 260                                      Commerce, vente
# 301                                Comptabilité, gestion
# 449                                       Travail social
# ...                                                  ...
# 38608                                                NaN
# 38709                               Formations générales
# 38869               Bâtiment: construction et couverture
# 38892           Technologies industrielles fondamentales
# 39263  Autres disciplines artistiques et spécialités ...
#
#                                                Activite2  \
# 169                                                  NaN
# 187                                            Autres...
# 260    Ressources humaines, gestion du personnel, ges...
# 301                                                  NaN
# 449                              Enseignement, formation
# ...                                                  ...
# 38608                                                NaN
# 38709                                    Commerce, vente
# 38869  Sécurité des biens et des personnes, police, s...
# 38892                                                NaN
# 39263         Techniques de l'imprimerie et de l'édition
#
#                    Activite3                       Adresse  CodePostale  \
# 169                      NaN               140 RUE DE LORS      87380.0
# 187                      NaN         29 RUE ROMAIN ROLLAND      44100.0
# 260                      NaN                           NaN          NaN
# 301                      NaN  27 CHEMIN DE LA CAVERNE N°17      97434.0
# 449                      NaN                           NaN          NaN
# ...                      ...                           ...          ...
# 38608                    NaN                           NaN          NaN
# 38709  Comptabilité, gestion                   36 RUE CLER      75007.0
# 38869                    NaN           10 RUE DES CIGOGNES      97480.0
# 38892                    NaN            1 CHEMIN DE L'ONDE      44240.0
# 39263                    NaN          24, quai de la Fosse      44000.0
#
#                        Ville           Siret    IDS        Statut
# 169                  GLANGES  81063315600015  140.0  Pas Qualiopi
# 187                   NANTES  50316997100010  140.0  Pas Qualiopi
# 260                      NaN  85297199300021  140.0  Pas Qualiopi
# 301                  ST PAUL  52340659300021  140.0  Pas Qualiopi
# 449                      NaN  84931718500015  140.0  Pas Qualiopi
# ...                      ...             ...    ...           ...
# 38608                    NaN  85205528400016  140.0  Pas Qualiopi
# 38709               PARIS 07  44922655400060  140.0  Pas Qualiopi
# 38869              ST JOSEPH  91812767100017  140.0  Pas Qualiopi
# 38892  LA CHAPELLE SUR ERDRE  52338497200023  140.0  Pas Qualiopi
# 39263                 NANTES  33864179800016  140.0  Pas Qualiopi
#
# [473 rows x 15 columns]

# %%
import pandas as pd

file_path = 'Non_Matching_Siret_YAV_Results.csv'

df = pd.read_csv(file_path)

colonnes_a_conserver = [
    'ID', 'nom', 'Email', 'Crée', 'Mobile', 'Activite1', 'Activite2', 'Activite3', 'Adresse', 'CodePostale', 'Ville', 'Siret','Statut'
]

df_filtré = df[colonnes_a_conserver]

df_filtré
# Out:
#          ID                                               nom Email  \
# 0       702                                               A2O   NaN
# 1       760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN   NaN
# 2       968                             ABConsultant & Net Oi   NaN
# 3      1094                                      AB FORMATION   NaN
# 4      1568                                            ACCEVA   NaN
# ..      ...                                               ...   ...
# 468  129254                                  PICANTIN Olivier   NaN
# 469  129514                   PIERSON DOMINIQUE (DP TRAINING)   NaN
# 470  129972                                PLUMES DE CIGOGNES   NaN
# 471  130040                                    PMO SUSTAINING   NaN
# 472  131138                                 PRO ARTE GRAPHICA   NaN
#
#                           Crée  Mobile  \
# 0    2023-06-09T10:32:42+03:00     NaN
# 1    2023-06-09T10:32:45+03:00     NaN
# 2    2023-06-09T10:32:53+03:00     NaN
# 3    2023-06-09T10:32:58+03:00     NaN
# 4    2023-06-09T10:33:18+03:00     NaN
# ..                         ...     ...
# 468  2023-06-09T17:19:45+03:00     NaN
# 469  2023-06-09T17:19:53+03:00     NaN
# 470  2023-06-09T17:20:09+03:00     NaN
# 471  2023-06-09T17:20:12+03:00     NaN
# 472  2023-06-09T17:20:49+03:00     NaN
#
#                                              Activite1  \
# 0    Développement des capacités d'orientation, d'i...
# 1                                 Formations générales
# 2                                      Commerce, vente
# 3                                Comptabilité, gestion
# 4                                       Travail social
# ..                                                 ...
# 468                                                NaN
# 469                               Formations générales
# 470               Bâtiment: construction et couverture
# 471           Technologies industrielles fondamentales
# 472  Autres disciplines artistiques et spécialités ...
#
#                                              Activite2              Activite3  \
# 0                                                  NaN                    NaN
# 1                                            Autres...                    NaN
# 2    Ressources humaines, gestion du personnel, ges...                    NaN
# 3                                                  NaN                    NaN
# 4                              Enseignement, formation                    NaN
# ..                                                 ...                    ...
# 468                                                NaN                    NaN
# 469                                    Commerce, vente  Comptabilité, gestion
# 470  Sécurité des biens et des personnes, police, s...                    NaN
# 471                                                NaN                    NaN
# 472         Techniques de l'imprimerie et de l'édition                    NaN
#
#                           Adresse  CodePostale                  Ville  \
# 0                 140 RUE DE LORS      87380.0                GLANGES
# 1           29 RUE ROMAIN ROLLAND      44100.0                 NANTES
# 2                             NaN          NaN                    NaN
# 3    27 CHEMIN DE LA CAVERNE N°17      97434.0                ST PAUL
# 4                             NaN          NaN                    NaN
# ..                            ...          ...                    ...
# 468                           NaN          NaN                    NaN
# 469                   36 RUE CLER      75007.0               PARIS 07
# 470           10 RUE DES CIGOGNES      97480.0              ST JOSEPH
# 471            1 CHEMIN DE L'ONDE      44240.0  LA CHAPELLE SUR ERDRE
# 472          24, quai de la Fosse      44000.0                 NANTES
#
#               Siret        Statut
# 0    81063315600015  Pas Qualiopi
# 1    50316997100010  Pas Qualiopi
# 2    85297199300021  Pas Qualiopi
# 3    52340659300021  Pas Qualiopi
# 4    84931718500015  Pas Qualiopi
# ..              ...           ...
# 468  85205528400016  Pas Qualiopi
# 469  44922655400060  Pas Qualiopi
# 470  91812767100017  Pas Qualiopi
# 471  52338497200023  Pas Qualiopi
# 472  33864179800016  Pas Qualiopi
#
# [473 rows x 13 columns]

# %%
df_filtré.to_csv('df_filtre_Non_Matching_Siret_YAV_Results.csv', index=False)
df_filtré
# Out:
#          ID                                               nom Email  \
# 0       702                                               A2O   NaN
# 1       760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN   NaN
# 2       968                             ABConsultant & Net Oi   NaN
# 3      1094                                      AB FORMATION   NaN
# 4      1568                                            ACCEVA   NaN
# ..      ...                                               ...   ...
# 468  129254                                  PICANTIN Olivier   NaN
# 469  129514                   PIERSON DOMINIQUE (DP TRAINING)   NaN
# 470  129972                                PLUMES DE CIGOGNES   NaN
# 471  130040                                    PMO SUSTAINING   NaN
# 472  131138                                 PRO ARTE GRAPHICA   NaN
#
#                           Crée  Mobile  \
# 0    2023-06-09T10:32:42+03:00     NaN
# 1    2023-06-09T10:32:45+03:00     NaN
# 2    2023-06-09T10:32:53+03:00     NaN
# 3    2023-06-09T10:32:58+03:00     NaN
# 4    2023-06-09T10:33:18+03:00     NaN
# ..                         ...     ...
# 468  2023-06-09T17:19:45+03:00     NaN
# 469  2023-06-09T17:19:53+03:00     NaN
# 470  2023-06-09T17:20:09+03:00     NaN
# 471  2023-06-09T17:20:12+03:00     NaN
# 472  2023-06-09T17:20:49+03:00     NaN
#
#                                              Activite1  \
# 0    Développement des capacités d'orientation, d'i...
# 1                                 Formations générales
# 2                                      Commerce, vente
# 3                                Comptabilité, gestion
# 4                                       Travail social
# ..                                                 ...
# 468                                                NaN
# 469                               Formations générales
# 470               Bâtiment: construction et couverture
# 471           Technologies industrielles fondamentales
# 472  Autres disciplines artistiques et spécialités ...
#
#                                              Activite2              Activite3  \
# 0                                                  NaN                    NaN
# 1                                            Autres...                    NaN
# 2    Ressources humaines, gestion du personnel, ges...                    NaN
# 3                                                  NaN                    NaN
# 4                              Enseignement, formation                    NaN
# ..                                                 ...                    ...
# 468                                                NaN                    NaN
# 469                                    Commerce, vente  Comptabilité, gestion
# 470  Sécurité des biens et des personnes, police, s...                    NaN
# 471                                                NaN                    NaN
# 472         Techniques de l'imprimerie et de l'édition                    NaN
#
#                           Adresse  CodePostale                  Ville  \
# 0                 140 RUE DE LORS      87380.0                GLANGES
# 1           29 RUE ROMAIN ROLLAND      44100.0                 NANTES
# 2                             NaN          NaN                    NaN
# 3    27 CHEMIN DE LA CAVERNE N°17      97434.0                ST PAUL
# 4                             NaN          NaN                    NaN
# ..                            ...          ...                    ...
# 468                           NaN          NaN                    NaN
# 469                   36 RUE CLER      75007.0               PARIS 07
# 470           10 RUE DES CIGOGNES      97480.0              ST JOSEPH
# 471            1 CHEMIN DE L'ONDE      44240.0  LA CHAPELLE SUR ERDRE
# 472          24, quai de la Fosse      44000.0                 NANTES
#
#               Siret        Statut
# 0    81063315600015  Pas Qualiopi
# 1    50316997100010  Pas Qualiopi
# 2    85297199300021  Pas Qualiopi
# 3    52340659300021  Pas Qualiopi
# 4    84931718500015  Pas Qualiopi
# ..              ...           ...
# 468  85205528400016  Pas Qualiopi
# 469  44922655400060  Pas Qualiopi
# 470  91812767100017  Pas Qualiopi
# 471  52338497200023  Pas Qualiopi
# 472  33864179800016  Pas Qualiopi
#
# [473 rows x 13 columns]

# %% [markdown]
# <span style="color: black; font-weight: bold; font-size: 50px;">Traitement des entreprises Pas Qualiopi (Yav) qui ont changé de statut voir si elles sont Qualiopi ou fermé.</span>

# %%
import pandas as pd

file1_path = 'df_filtre_Non_Matching_Siret_YAV_Results.csv'
file2_path = 'listesdesqualiopietnon.csv'

try:
    companyyav_df = pd.read_csv(file1_path)
    all_records_export_df = pd.read_csv(file2_path, delimiter=',', on_bad_lines='skip', low_memory=False)
except pd.errors.ParserError as e:
    print(f"Erreur lors de la lecture des fichiers CSV : {e}")

if 'companyyav_df' in locals() and 'all_records_export_df' in locals():
    print("Colonnes disponibles dans 'listesdesqualiopietnon.csv' :")
    print(all_records_export_df.columns)

    if 'siretetablissementdeclarant' in all_records_export_df.columns:
        companyyav_df['Siret'] = companyyav_df['Siret'].astype(str).str.replace(r'\.0$', '', regex=True).str.strip()
        all_records_export_df['siretetablissementdeclarant'] = all_records_export_df['siretetablissementdeclarant'].astype(str).str.strip()

        print(f"Exemples de SIRET dans 'companyyav.csv' : {companyyav_df['Siret'].head()}")
        print(f"Exemples de SIRET dans 'listesdesqualiopietnon.csv' : {all_records_export_df['siretetablissementdeclarant'].head()}")

        unique_siret_companyyav = companyyav_df['Siret'].nunique()
        unique_siret_all_records = all_records_export_df['siretetablissementdeclarant'].nunique()

        print(f"Nombre de SIRET uniques dans 'companyyav.csv': {unique_siret_companyyav}")
        print(f"Nombre de SIRET uniques dans 'listesdesqualiopietnon.csv': {unique_siret_all_records}")

        common_values = companyyav_df[companyyav_df['Siret'].isin(all_records_export_df['siretetablissementdeclarant'])]
        print(f"Nombre de correspondances trouvées: {common_values.shape[0]}")

        merged_dfs = pd.merge(common_values, all_records_export_df, left_on='Siret', right_on='siretetablissementdeclarant')

        print("\nInformations des valeurs communes dans 'Siret' et 'siretetablissementdeclarant':")
        print(merged_dfs.head()) 

        missing_siret_in_all_recordss = companyyav_df[~companyyav_df['Siret'].isin(all_records_export_df['siretetablissementdeclarant'])]
        print(f"Nombre de SIRET dans 'companyyav.csv' non trouvés dans 'listesdesqualiopietnon.csv': {missing_siret_in_all_records.shape[0]}")
        print(missing_siret_in_all_recordss.head())
    else:
        print("La colonne 'siretetablissementdeclarant' n'existe pas dans le fichier 'listesdesqualiopietnon.csv'.")
else:
    print("Les fichiers n'ont pas pu être chargés correctement.")
# Out:
# Colonnes disponibles dans 'listesdesqualiopietnon.csv' :
# Index(['numerodeclarationactivite', 'numerosdeclarationactiviteprecedent',
#        'denomination', 'siren', 'siretetablissementdeclarant',
#        'adressephysiqueorganismeformation_voie',
#        'adressephysiqueorganismeformation_codepostal',
#        'adressephysiqueorganismeformation_ville',
#        'adressephysiqueorganismeformation_coderegion', 'geocodageban',
#        'certifications_actionsdeformation',
#        'certifications_bilansdecompetences', 'certifications_vae',
#        'certifications_actionsdeformationparapprentissage',
#        'organismeetrangerrepresente_denomination',
#        'organismeetrangerrepresente_voie',
#        'organismeetrangerrepresente_codepostal',
#        'organismeetrangerrepresente_ville', 'organismeetrangerrepresente_pays',
#        'informationsdeclarees_datedernieredeclaration',
#        'informationsdeclarees_debutexercice',
#        'informationsdeclarees_finexercice',
#        'informationsdeclarees_specialitesdeformation_codespecialite1',
#        'informationsdeclarees_specialitesdeformation_libellespecialite1',
#        'informationsdeclarees_specialitesdeformation_codespecialite2',
#        'informationsdeclarees_specialitesdeformation_libellespecialite2',
#        'informationsdeclarees_specialitesdeformation_codespecialite3',
#        'informationsdeclarees_specialitesdeformation_libellespecialite3',
#        'informationsdeclarees_nbstagiaires',
#        'informationsdeclarees_nbstagiairesconfiesparunautreof',
#        'informationsdeclarees_effectifformateurs', 'com_arm_code',
#        'com_arm_name', 'epci_code', 'epci_name', 'dep_code', 'dep_name',
#        'reg_name', 'reg_code', 'toutes_specialites',
#        'organisme_formation_geocode', 'certifications', 'random_id'],
#       dtype='object')
# Exemples de SIRET dans 'companyyav.csv' : 0    81063315600015
# 1    50316997100010
# 2    85297199300021
# 3    52340659300021
# 4    84931718500015
# Name: Siret, dtype: object
# Exemples de SIRET dans 'listesdesqualiopietnon.csv' : 0    89017665400014
# 1    33506030700063
# 2    89461217500014
# 3    80188068300025
# 4    82164621300024
# Name: siretetablissementdeclarant, dtype: object
# Nombre de SIRET uniques dans 'companyyav.csv': 473
# Nombre de SIRET uniques dans 'listesdesqualiopietnon.csv': 134382
# Nombre de correspondances trouvées: 28
#
# Informations des valeurs communes dans 'Siret' et 'siretetablissementdeclarant':
#       ID                            nom Email                       Crée  \
# 0    702                            A2O   NaN  2023-06-09T10:32:42+03:00
# 1   4034  AGENCE DE VOYAGES IMAGINAIRES   NaN  2023-06-09T10:34:56+03:00
# 2  14800               AUTO ECOLE MITTY   NaN  2023-06-09T10:41:25+03:00
# 3  15644              AYALA CONSEILS RH   NaN  2023-06-09T10:41:54+03:00
# 4  19648               BOUCHET PHILIPPE   NaN  2023-06-09T10:44:15+03:00
#
#    Mobile                                          Activite1  \
# 0     NaN  Développement des capacités d'orientation, d'i...
# 1     NaN                         Musique, arts du spectacle
# 2     NaN                            Enseignement, formation
# 3     NaN  Ressources humaines, gestion du personnel, ges...
# 4     NaN                                    Commerce, vente
#
#                                            Activite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Sécurité des biens et des personnes, police, s...
#
#                                            Activite3          Adresse  \
# 0                                                NaN  140 RUE DE LORS
# 1                                                NaN              NaN
# 2                                                NaN      1 AV DE BRY
# 3                                                NaN              NaN
# 4  Développement des capacités comportementales e...              NaN
#
#    CodePostale  ...    epci_code  \
# 0      87380.0  ...  200040814.0
# 1          NaN  ...  200054807.0
# 2      94170.0  ...  200054781.0
# 3          NaN  ...          NaN
# 4          NaN  ...          NaN
#
#                                          epci_name dep_code  \
# 0  Communauté de communes Briance Sud Haute Vienne       87
# 1               Métropole d'Aix-Marseille-Provence       13
# 2                         Métropole du Grand Paris       94
# 3                                              NaN      NaN
# 4                                              NaN      NaN
#
#             dep_name                    reg_name reg_code  \
# 0       Haute-Vienne          Nouvelle-Aquitaine       75
# 1   Bouches-du-Rhône  Provence-Alpes-Côte d'Azur       93
# 2       Val-de-Marne               Île-de-France       11
# 3  Pas de départment          Nouvelle-Aquitaine       75
# 4  Pas de départment        Auvergne-Rhône-Alpes       84
#
#                                   toutes_specialites  \
# 0  Développement des capacités d'orientation, d'i...
# 1                         Musique, arts du spectacle
# 2                            Enseignement, formation
# 3  Ressources humaines, gestion du personnel, ges...
# 4  Sécurité des biens et des personnes, police, s...
#
#   organisme_formation_geocode                               certifications  \
# 0                        True                        Bilans de compétences
# 1                        True                        Actions de formations
# 2                        True                        Actions de formations
# 3                       False  Actions de formations,Bilans de compétences
# 4                       False                        Actions de formations
#
#    random_id
# 0  32.215638
# 1  84.194779
# 2  64.745143
# 3  73.588300
# 4  59.103676
#
# [5 rows x 56 columns]
# Nombre de SIRET dans 'companyyav.csv' non trouvés dans 'listesdesqualiopietnon.csv': 1520
#      ID                                               nom Email  \
# 1   760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN   NaN
# 2   968                             ABConsultant & Net Oi   NaN
# 3  1094                                      AB FORMATION   NaN
# 4  1568                                            ACCEVA   NaN
# 5  1584                        ACCIOR LES SABLES D'OLONNE   NaN
#
#                         Crée  Mobile              Activite1  \
# 1  2023-06-09T10:32:45+03:00     NaN   Formations générales
# 2  2023-06-09T10:32:53+03:00     NaN        Commerce, vente
# 3  2023-06-09T10:32:58+03:00     NaN  Comptabilité, gestion
# 4  2023-06-09T10:33:18+03:00     NaN         Travail social
# 5  2023-06-09T10:33:18+03:00     NaN  Comptabilité, gestion
#
#                                            Activite2 Activite3  \
# 1                                          Autres...       NaN
# 2  Ressources humaines, gestion du personnel, ges...       NaN
# 3                                                NaN       NaN
# 4                            Enseignement, formation       NaN
# 5  Ressources humaines, gestion du personnel, ges...       NaN
#
#                         Adresse  CodePostale    Ville           Siret  \
# 1         29 RUE ROMAIN ROLLAND      44100.0   NANTES  50316997100010
# 2                           NaN          NaN      NaN  85297199300021
# 3  27 CHEMIN DE LA CAVERNE N°17      97434.0  ST PAUL  52340659300021
# 4                           NaN          NaN      NaN  84931718500015
# 5                           NaN          NaN      NaN  32890745600029
#
#          Statut
# 1  Pas Qualiopi
# 2  Pas Qualiopi
# 3  Pas Qualiopi
# 4  Pas Qualiopi
# 5  Pas Qualiopi

# %%
merged_dfs.to_csv("Liste_des_entreprises_qui_ont_change_de_statut_et_qui_se_trouve_dans_dgefp.csv", index=False)
merged_dfs
# Out:
#         ID                                       nom Email  \
# 0      702                                       A2O   NaN
# 1     4034             AGENCE DE VOYAGES IMAGINAIRES   NaN
# 2    14800                          AUTO ECOLE MITTY   NaN
# 3    15644                         AYALA CONSEILS RH   NaN
# 4    19648                          BOUCHET PHILIPPE   NaN
# 5    21532                     CABINET DE PORT ROYAL   NaN
# 6    26914                            CHILLA FRANCIS   NaN
# 7    30438  CONSEIL ARCHITEC URBANISME ENVIRONNEMENT   NaN
# 8    39228                                   EFFILAB   NaN
# 9    39966                                    ELEVOL   NaN
# 10   43678                            EVOL EDUCATION   NaN
# 11   44422                            FABULOUS.PARIS   NaN
# 12   47326                                  FORMA-PY   NaN
# 13   49958                   GATTINI-LOBSANG VALERIE   NaN
# 14   52902                            GUEGAN CORINNE   NaN
# 15   54390                              HEMIS FR SAS   NaN
# 16   55244                             Horizon Jeune   NaN
# 17   58426         I-NT  CONSEIL ET FORMATION - EURL   NaN
# 18   58556       INTERNATIONAL DEVELOPPEMENT SYSTEME   NaN
# 19   60072                              JC AUTO MOTO   NaN
# 20   69298                         LIESSE AUTO ECOLE   NaN
# 21   69362                  LIGONES-LAFFORT BEATRICE   NaN
# 22   70480                       LOUIS Isabelle (EI)   NaN
# 23  102446                      Mon Analyse Foncière   NaN
# 24  102938                  Monsieur ALAIN GONCALVES   NaN
# 25  123050                                   NEWO RH   NaN
# 26  125670                         OPTIMAL-IT SYSTEM   NaN
# 27  129514           PIERSON DOMINIQUE (DP TRAINING)   NaN
#
#                          Crée  Mobile  \
# 0   2023-06-09T10:32:42+03:00     NaN
# 1   2023-06-09T10:34:56+03:00     NaN
# 2   2023-06-09T10:41:25+03:00     NaN
# 3   2023-06-09T10:41:54+03:00     NaN
# 4   2023-06-09T10:44:15+03:00     NaN
# 5   2023-06-09T11:33:33+03:00     NaN
# 6   2023-06-09T12:12:02+03:00     NaN
# 7   2023-06-09T12:14:31+03:00     NaN
# 8   2023-06-09T12:20:39+03:00     NaN
# 9   2023-06-09T12:21:06+03:00     NaN
# 10  2023-06-09T12:57:58+03:00     NaN
# 11  2023-06-09T12:58:31+03:00     NaN
# 12  2023-06-09T13:00:28+03:00     NaN
# 13  2023-06-09T13:02:04+03:00     NaN
# 14  2023-06-09T13:03:51+03:00     NaN
# 15  2023-06-09T13:04:42+03:00     NaN
# 16  2023-06-09T13:06:09+03:00     NaN
# 17  2023-06-09T13:07:57+03:00     NaN
# 18  2023-06-09T13:08:02+03:00     NaN
# 19  2023-06-09T15:39:20+03:00     NaN
# 20  2023-06-09T15:45:12+03:00     NaN
# 21  2023-06-09T15:45:14+03:00     NaN
# 22  2023-06-09T15:45:53+03:00     NaN
# 23  2023-06-09T16:48:50+03:00     NaN
# 24  2023-06-09T16:49:08+03:00     NaN
# 25  2023-06-09T17:16:12+03:00     NaN
# 26  2023-06-09T17:17:43+03:00     NaN
# 27  2023-06-09T17:19:53+03:00     NaN
#
#                                             Activite1  \
# 0   Développement des capacités d'orientation, d'i...
# 1                          Musique, arts du spectacle
# 2                             Enseignement, formation
# 3   Ressources humaines, gestion du personnel, ges...
# 4                                     Commerce, vente
# 5                                               Santé
# 6   Métallurgie (y compris sidérurgie, fonderie, n...
# 7                          Droit, sciences politiques
# 8       Spécialités plurivalentes de la communication
# 9   Développement des capacités comportementales e...
# 10                                     Travail social
# 11  Coiffure, esthétique et autres spécialités des...
# 12                               Formations générales
# 13                                              Santé
# 14                                                NaN
# 15  Développement des capacités comportementales e...
# 16  Développement des capacités d'orientation, d'i...
# 17  Informatique, traitement de l'information, rés...
# 18                                     Travail social
# 19                            Enseignement, formation
# 20                            Enseignement, formation
# 21  Spécialités plurivalentes des échanges et de l...
# 22                                        Psychologie
# 23                                          Autres...
# 24  Sécurité des biens et des personnes, police, s...
# 25  Ressources humaines, gestion du personnel, ges...
# 26  Documentation, bibliothèques, administration d...
# 27                               Formations générales
#
#                                             Activite2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Sécurité des biens et des personnes, police, s...
# 5                             Enseignement, formation
# 6                              Structures métalliques
# 7                                     Arts plastiques
# 8                                                 NaN
# 9   Développement des capacités individuelles d'or...
# 10                            Enseignement, formation
# 11                                                NaN
# 12         Spécialités concernant plusieurs capacités
# 13       Animation culturelle, sportive et de loisirs
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Développement des capacités comportementales e...
# 22  Ressources humaines, gestion du personnel, ges...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  Informatique, traitement de l'information, rés...
# 27                                    Commerce, vente
#
#                                             Activite3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Développement des capacités comportementales e...
# 5                                                 NaN
# 6                                                 NaN
# 7                                 Bâtiment: finitions
# 8                                                 NaN
# 9   Développement des capacités d'orientation, d'i...
# 10       Animation culturelle, sportive et de loisirs
# 11                                                NaN
# 12                                                NaN
# 13                                Pratiques sportives
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                              Santé
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                              Comptabilité, gestion
#
#                                    Adresse  CodePostale  ...    epci_code  \
# 0                          140 RUE DE LORS      87380.0  ...  200040814.0
# 1                                      NaN          NaN  ...  200054807.0
# 2                              1 AV DE BRY      94170.0  ...  200054781.0
# 3                                      NaN          NaN  ...          NaN
# 4                                      NaN          NaN  ...          NaN
# 5                                      NaN          NaN  ...  200054781.0
# 6                  64 BIS ROUTE DE LOURDES      65290.0  ...  200069300.0
# 7                    26 PL VINCENT RASPAIL      83000.0  ...  248300543.0
# 8                                      NaN          NaN  ...          NaN
# 9                                      NaN          NaN  ...  200059889.0
# 10            36 RUE BOCQUET FLOCHEL BP 40      62000.0  ...  200033579.0
# 11                                     NaN          NaN  ...          NaN
# 12                                     NaN          NaN  ...          NaN
# 13                2690, route des Amerands      74170.0  ...  200034882.0
# 14                                     NaN          NaN  ...          NaN
# 15                                     NaN          NaN  ...          NaN
# 16                   14 C RUE DES FUSILLES      23200.0  ...  200044014.0
# 17                     07 RUE DES FOUGERES      37420.0  ...  200072650.0
# 18     292 RUE CAMILLE GUERIN ST SO BAZAAR      59000.0  ...  200093201.0
# 19                 8 QUAI DE LA REPUBLIQUE      17100.0  ...  200036473.0
# 20                16 RUE DU CHAMP GAILLARD      95310.0  ...  249500109.0
# 21  CHALLENGE INNOVATION 7 RUE DE LA SERRE      31490.0  ...  243100781.0
# 22                  16 rue des flots bleus      56270.0  ...  200042174.0
# 23                                     NaN          NaN  ...          NaN
# 24                                     NaN          NaN  ...          NaN
# 25                   65 AV DE LA BRASSERIE      33260.0  ...  243300563.0
# 26                     19 RTE DE BESSIERES      31240.0  ...  243100518.0
# 27                             36 RUE CLER      75007.0  ...  200054781.0
#
#                                             epci_name dep_code  \
# 0     Communauté de communes Briance Sud Haute Vienne       87
# 1                  Métropole d'Aix-Marseille-Provence       13
# 2                            Métropole du Grand Paris       94
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                            Métropole du Grand Paris       75
# 6   Communauté d'agglomération Tarbes-Lourdes-Pyré...       65
# 7              Métropole Toulon-Provence-Méditerranée       83
# 8                                                 NaN      NaN
# 9        Communauté urbaine Grand Paris Seine et Oise       78
# 10                         Communauté urbaine d'Arras       62
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13          Communauté de communes Pays du Mont-Blanc       74
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16            Communauté de communes Creuse Grand Sud       23
# 17  Communauté de communes Touraine Vallée de l'Indre       37
# 18                      Métropole Européenne de Lille       59
# 19  Communauté d'agglomération de Saintes - Grande...       17
# 20       Communauté d'agglomération de Cergy-Pontoise       95
# 21   Communauté de communes Le Grand Ouest Toulousain       31
# 22   Communauté d'agglomération Lorient Agglomération       56
# 23                                                NaN      NaN
# 24                                                NaN      NaN
# 25  Communauté d'agglomération Bassin d'Arcachon S...       33
# 26                                 Toulouse Métropole       31
# 27                           Métropole du Grand Paris       75
#
#              dep_name                    reg_name reg_code  \
# 0        Haute-Vienne          Nouvelle-Aquitaine       75
# 1    Bouches-du-Rhône  Provence-Alpes-Côte d'Azur       93
# 2        Val-de-Marne               Île-de-France       11
# 3   Pas de départment          Nouvelle-Aquitaine       75
# 4   Pas de départment        Auvergne-Rhône-Alpes       84
# 5               Paris               Île-de-France       11
# 6     Hautes-Pyrénées                   Occitanie       76
# 7                 Var  Provence-Alpes-Côte d'Azur       93
# 8   Pas de départment               Île-de-France       11
# 9            Yvelines               Île-de-France       11
# 10      Pas-de-Calais             Hauts-de-France       32
# 11  Pas de départment               Île-de-France       11
# 12  Pas de départment            Pays de la Loire       52
# 13       Haute-Savoie        Auvergne-Rhône-Alpes       84
# 14  Pas de départment             Hauts-de-France       32
# 15  Pas de départment             Hauts-de-France       32
# 16             Creuse          Nouvelle-Aquitaine       75
# 17     Indre-et-Loire         Centre-Val de Loire       24
# 18               Nord             Hauts-de-France       32
# 19  Charente-Maritime          Nouvelle-Aquitaine       75
# 20         Val-d'Oise               Île-de-France       11
# 21      Haute-Garonne                   Occitanie       76
# 22           Morbihan                    Bretagne       53
# 23  Pas de départment               Île-de-France       11
# 24  Pas de départment               Île-de-France       11
# 25            Gironde          Nouvelle-Aquitaine       75
# 26      Haute-Garonne                   Occitanie       76
# 27              Paris               Île-de-France       11
#
#                                    toutes_specialites  \
# 0   Développement des capacités d'orientation, d'i...
# 1                          Musique, arts du spectacle
# 2                             Enseignement, formation
# 3   Ressources humaines, gestion du personnel, ges...
# 4   Sécurité des biens et des personnes, police, s...
# 5                                               Santé
# 6   Formations générales,Métallurgie (y compris si...
# 7   Aménagement du territoire, développement, urba...
# 8       Spécialités plurivalentes de la communication
# 9   Développement des capacités individuelles d'or...
# 10                                     Travail social
# 11  Coiffure, esthétique et autres spécialités des...
# 12                               Formations générales
# 13                                Pratiques sportives
# 14                                                NaN
# 15  Développement des capacités comportementales e...
# 16  Développement des capacités d'orientation, d'i...
# 17  Informatique, traitement de l'information, rés...
# 18                                     Travail social
# 19                            Enseignement, formation
# 20                            Enseignement, formation
# 21  Développement des capacités comportementales e...
# 22  Spécialités pluridisciplinaires, sciences huma...
# 23  Aménagement du territoire, développement, urba...
# 24  Sécurité des biens et des personnes, police, s...
# 25  Ressources humaines, gestion du personnel, ges...
# 26  Informatique, traitement de l'information, rés...
# 27  Formations générales,Commerce, vente,Comptabil...
#
#    organisme_formation_geocode                               certifications  \
# 0                         True                        Bilans de compétences
# 1                         True                        Actions de formations
# 2                         True                        Actions de formations
# 3                        False  Actions de formations,Bilans de compétences
# 4                        False                        Actions de formations
# 5                         True                        Actions de formations
# 6                         True                        Actions de formations
# 7                         True                        Actions de formations
# 8                        False                        Actions de formations
# 9                         True  Actions de formations,Bilans de compétences
# 10                        True                        Actions de formations
# 11                       False      Actions de formations par apprentissage
# 12                       False                        Actions de formations
# 13                        True                        Actions de formations
# 14                       False  Actions de formations,Bilans de compétences
# 15                       False                        Actions de formations
# 16                        True                        Actions de formations
# 17                        True                        Actions de formations
# 18                        True                        Actions de formations
# 19                        True                        Actions de formations
# 20                        True                        Actions de formations
# 21                        True                        Actions de formations
# 22                        True                        Actions de formations
# 23                       False                        Actions de formations
# 24                       False                        Actions de formations
# 25                        True                        Actions de formations
# 26                        True                        Actions de formations
# 27                        True                        Actions de formations
#
#     random_id
# 0   32.215638
# 1   84.194779
# 2   64.745143
# 3   73.588300
# 4   59.103676
# 5   54.166305
# 6   62.916227
# 7   89.968066
# 8   13.557677
# 9   83.273431
# 10  76.693079
# 11   0.455877
# 12  58.976241
# 13   8.520535
# 14  26.787058
# 15  62.373002
# 16  11.076358
# 17  68.847214
# 18   3.659532
# 19  83.735294
# 20  10.176485
# 21  62.194901
# 22  16.443552
# 23  20.723553
# 24  90.945398
# 25  55.999881
# 26   7.371078
# 27  52.603892
#
# [28 rows x 56 columns]

# %%
import pandas as pd

df = pd.read_csv("Liste_des_entreprises_qui_ont_change_de_statut_et_qui_se_trouve_dans_dgefp.csv", encoding='utf-8', low_memory=False)

colonnes_a_verifier = [
    'certifications_actionsdeformation', 
    'certifications_bilansdecompetences', 
    'certifications_vae', 
    'certifications_actionsdeformationparapprentissage'
]

df_non_vide = df.dropna(subset=colonnes_a_verifier, how='all')

df_non_vide.to_csv("Les_qualiopi_dans_la_liste_des_entreprises_qui_ont_change_leur_statut.csv", index=False)
df_non_vide
# Out:
#         ID                                       nom  Email  \
# 0      702                                       A2O    NaN
# 1     4034             AGENCE DE VOYAGES IMAGINAIRES    NaN
# 2    14800                          AUTO ECOLE MITTY    NaN
# 3    15644                         AYALA CONSEILS RH    NaN
# 4    19648                          BOUCHET PHILIPPE    NaN
# 5    21532                     CABINET DE PORT ROYAL    NaN
# 6    26914                            CHILLA FRANCIS    NaN
# 7    30438  CONSEIL ARCHITEC URBANISME ENVIRONNEMENT    NaN
# 8    39228                                   EFFILAB    NaN
# 9    39966                                    ELEVOL    NaN
# 10   43678                            EVOL EDUCATION    NaN
# 11   44422                            FABULOUS.PARIS    NaN
# 12   47326                                  FORMA-PY    NaN
# 13   49958                   GATTINI-LOBSANG VALERIE    NaN
# 14   52902                            GUEGAN CORINNE    NaN
# 15   54390                              HEMIS FR SAS    NaN
# 16   55244                             Horizon Jeune    NaN
# 17   58426         I-NT  CONSEIL ET FORMATION - EURL    NaN
# 18   58556       INTERNATIONAL DEVELOPPEMENT SYSTEME    NaN
# 19   60072                              JC AUTO MOTO    NaN
# 20   69298                         LIESSE AUTO ECOLE    NaN
# 21   69362                  LIGONES-LAFFORT BEATRICE    NaN
# 22   70480                       LOUIS Isabelle (EI)    NaN
# 23  102446                      Mon Analyse Foncière    NaN
# 24  102938                  Monsieur ALAIN GONCALVES    NaN
# 25  123050                                   NEWO RH    NaN
# 26  125670                         OPTIMAL-IT SYSTEM    NaN
# 27  129514           PIERSON DOMINIQUE (DP TRAINING)    NaN
#
#                          Crée  Mobile  \
# 0   2023-06-09T10:32:42+03:00     NaN
# 1   2023-06-09T10:34:56+03:00     NaN
# 2   2023-06-09T10:41:25+03:00     NaN
# 3   2023-06-09T10:41:54+03:00     NaN
# 4   2023-06-09T10:44:15+03:00     NaN
# 5   2023-06-09T11:33:33+03:00     NaN
# 6   2023-06-09T12:12:02+03:00     NaN
# 7   2023-06-09T12:14:31+03:00     NaN
# 8   2023-06-09T12:20:39+03:00     NaN
# 9   2023-06-09T12:21:06+03:00     NaN
# 10  2023-06-09T12:57:58+03:00     NaN
# 11  2023-06-09T12:58:31+03:00     NaN
# 12  2023-06-09T13:00:28+03:00     NaN
# 13  2023-06-09T13:02:04+03:00     NaN
# 14  2023-06-09T13:03:51+03:00     NaN
# 15  2023-06-09T13:04:42+03:00     NaN
# 16  2023-06-09T13:06:09+03:00     NaN
# 17  2023-06-09T13:07:57+03:00     NaN
# 18  2023-06-09T13:08:02+03:00     NaN
# 19  2023-06-09T15:39:20+03:00     NaN
# 20  2023-06-09T15:45:12+03:00     NaN
# 21  2023-06-09T15:45:14+03:00     NaN
# 22  2023-06-09T15:45:53+03:00     NaN
# 23  2023-06-09T16:48:50+03:00     NaN
# 24  2023-06-09T16:49:08+03:00     NaN
# 25  2023-06-09T17:16:12+03:00     NaN
# 26  2023-06-09T17:17:43+03:00     NaN
# 27  2023-06-09T17:19:53+03:00     NaN
#
#                                             Activite1  \
# 0   Développement des capacités d'orientation, d'i...
# 1                          Musique, arts du spectacle
# 2                             Enseignement, formation
# 3   Ressources humaines, gestion du personnel, ges...
# 4                                     Commerce, vente
# 5                                               Santé
# 6   Métallurgie (y compris sidérurgie, fonderie, n...
# 7                          Droit, sciences politiques
# 8       Spécialités plurivalentes de la communication
# 9   Développement des capacités comportementales e...
# 10                                     Travail social
# 11  Coiffure, esthétique et autres spécialités des...
# 12                               Formations générales
# 13                                              Santé
# 14                                                NaN
# 15  Développement des capacités comportementales e...
# 16  Développement des capacités d'orientation, d'i...
# 17  Informatique, traitement de l'information, rés...
# 18                                     Travail social
# 19                            Enseignement, formation
# 20                            Enseignement, formation
# 21  Spécialités plurivalentes des échanges et de l...
# 22                                        Psychologie
# 23                                          Autres...
# 24  Sécurité des biens et des personnes, police, s...
# 25  Ressources humaines, gestion du personnel, ges...
# 26  Documentation, bibliothèques, administration d...
# 27                               Formations générales
#
#                                             Activite2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Sécurité des biens et des personnes, police, s...
# 5                             Enseignement, formation
# 6                              Structures métalliques
# 7                                     Arts plastiques
# 8                                                 NaN
# 9   Développement des capacités individuelles d'or...
# 10                            Enseignement, formation
# 11                                                NaN
# 12         Spécialités concernant plusieurs capacités
# 13       Animation culturelle, sportive et de loisirs
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Développement des capacités comportementales e...
# 22  Ressources humaines, gestion du personnel, ges...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  Informatique, traitement de l'information, rés...
# 27                                    Commerce, vente
#
#                                             Activite3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Développement des capacités comportementales e...
# 5                                                 NaN
# 6                                                 NaN
# 7                                 Bâtiment: finitions
# 8                                                 NaN
# 9   Développement des capacités d'orientation, d'i...
# 10       Animation culturelle, sportive et de loisirs
# 11                                                NaN
# 12                                                NaN
# 13                                Pratiques sportives
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                              Santé
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                              Comptabilité, gestion
#
#                                    Adresse  CodePostale  ...    epci_code  \
# 0                          140 RUE DE LORS      87380.0  ...  200040814.0
# 1                                      NaN          NaN  ...  200054807.0
# 2                              1 AV DE BRY      94170.0  ...  200054781.0
# 3                                      NaN          NaN  ...          NaN
# 4                                      NaN          NaN  ...          NaN
# 5                                      NaN          NaN  ...  200054781.0
# 6                  64 BIS ROUTE DE LOURDES      65290.0  ...  200069300.0
# 7                    26 PL VINCENT RASPAIL      83000.0  ...  248300543.0
# 8                                      NaN          NaN  ...          NaN
# 9                                      NaN          NaN  ...  200059889.0
# 10            36 RUE BOCQUET FLOCHEL BP 40      62000.0  ...  200033579.0
# 11                                     NaN          NaN  ...          NaN
# 12                                     NaN          NaN  ...          NaN
# 13                2690, route des Amerands      74170.0  ...  200034882.0
# 14                                     NaN          NaN  ...          NaN
# 15                                     NaN          NaN  ...          NaN
# 16                   14 C RUE DES FUSILLES      23200.0  ...  200044014.0
# 17                     07 RUE DES FOUGERES      37420.0  ...  200072650.0
# 18     292 RUE CAMILLE GUERIN ST SO BAZAAR      59000.0  ...  200093201.0
# 19                 8 QUAI DE LA REPUBLIQUE      17100.0  ...  200036473.0
# 20                16 RUE DU CHAMP GAILLARD      95310.0  ...  249500109.0
# 21  CHALLENGE INNOVATION 7 RUE DE LA SERRE      31490.0  ...  243100781.0
# 22                  16 rue des flots bleus      56270.0  ...  200042174.0
# 23                                     NaN          NaN  ...          NaN
# 24                                     NaN          NaN  ...          NaN
# 25                   65 AV DE LA BRASSERIE      33260.0  ...  243300563.0
# 26                     19 RTE DE BESSIERES      31240.0  ...  243100518.0
# 27                             36 RUE CLER      75007.0  ...  200054781.0
#
#                                             epci_name dep_code  \
# 0     Communauté de communes Briance Sud Haute Vienne     87.0
# 1                  Métropole d'Aix-Marseille-Provence     13.0
# 2                            Métropole du Grand Paris     94.0
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                            Métropole du Grand Paris     75.0
# 6   Communauté d'agglomération Tarbes-Lourdes-Pyré...     65.0
# 7              Métropole Toulon-Provence-Méditerranée     83.0
# 8                                                 NaN      NaN
# 9        Communauté urbaine Grand Paris Seine et Oise     78.0
# 10                         Communauté urbaine d'Arras     62.0
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13          Communauté de communes Pays du Mont-Blanc     74.0
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16            Communauté de communes Creuse Grand Sud     23.0
# 17  Communauté de communes Touraine Vallée de l'Indre     37.0
# 18                      Métropole Européenne de Lille     59.0
# 19  Communauté d'agglomération de Saintes - Grande...     17.0
# 20       Communauté d'agglomération de Cergy-Pontoise     95.0
# 21   Communauté de communes Le Grand Ouest Toulousain     31.0
# 22   Communauté d'agglomération Lorient Agglomération     56.0
# 23                                                NaN      NaN
# 24                                                NaN      NaN
# 25  Communauté d'agglomération Bassin d'Arcachon S...     33.0
# 26                                 Toulouse Métropole     31.0
# 27                           Métropole du Grand Paris     75.0
#
#              dep_name                    reg_name reg_code  \
# 0        Haute-Vienne          Nouvelle-Aquitaine       75
# 1    Bouches-du-Rhône  Provence-Alpes-Côte d'Azur       93
# 2        Val-de-Marne               Île-de-France       11
# 3   Pas de départment          Nouvelle-Aquitaine       75
# 4   Pas de départment        Auvergne-Rhône-Alpes       84
# 5               Paris               Île-de-France       11
# 6     Hautes-Pyrénées                   Occitanie       76
# 7                 Var  Provence-Alpes-Côte d'Azur       93
# 8   Pas de départment               Île-de-France       11
# 9            Yvelines               Île-de-France       11
# 10      Pas-de-Calais             Hauts-de-France       32
# 11  Pas de départment               Île-de-France       11
# 12  Pas de départment            Pays de la Loire       52
# 13       Haute-Savoie        Auvergne-Rhône-Alpes       84
# 14  Pas de départment             Hauts-de-France       32
# 15  Pas de départment             Hauts-de-France       32
# 16             Creuse          Nouvelle-Aquitaine       75
# 17     Indre-et-Loire         Centre-Val de Loire       24
# 18               Nord             Hauts-de-France       32
# 19  Charente-Maritime          Nouvelle-Aquitaine       75
# 20         Val-d'Oise               Île-de-France       11
# 21      Haute-Garonne                   Occitanie       76
# 22           Morbihan                    Bretagne       53
# 23  Pas de départment               Île-de-France       11
# 24  Pas de départment               Île-de-France       11
# 25            Gironde          Nouvelle-Aquitaine       75
# 26      Haute-Garonne                   Occitanie       76
# 27              Paris               Île-de-France       11
#
#                                    toutes_specialites  \
# 0   Développement des capacités d'orientation, d'i...
# 1                          Musique, arts du spectacle
# 2                             Enseignement, formation
# 3   Ressources humaines, gestion du personnel, ges...
# 4   Sécurité des biens et des personnes, police, s...
# 5                                               Santé
# 6   Formations générales,Métallurgie (y compris si...
# 7   Aménagement du territoire, développement, urba...
# 8       Spécialités plurivalentes de la communication
# 9   Développement des capacités individuelles d'or...
# 10                                     Travail social
# 11  Coiffure, esthétique et autres spécialités des...
# 12                               Formations générales
# 13                                Pratiques sportives
# 14                                                NaN
# 15  Développement des capacités comportementales e...
# 16  Développement des capacités d'orientation, d'i...
# 17  Informatique, traitement de l'information, rés...
# 18                                     Travail social
# 19                            Enseignement, formation
# 20                            Enseignement, formation
# 21  Développement des capacités comportementales e...
# 22  Spécialités pluridisciplinaires, sciences huma...
# 23  Aménagement du territoire, développement, urba...
# 24  Sécurité des biens et des personnes, police, s...
# 25  Ressources humaines, gestion du personnel, ges...
# 26  Informatique, traitement de l'information, rés...
# 27  Formations générales,Commerce, vente,Comptabil...
#
#     organisme_formation_geocode                               certifications  \
# 0                          True                        Bilans de compétences
# 1                          True                        Actions de formations
# 2                          True                        Actions de formations
# 3                         False  Actions de formations,Bilans de compétences
# 4                         False                        Actions de formations
# 5                          True                        Actions de formations
# 6                          True                        Actions de formations
# 7                          True                        Actions de formations
# 8                         False                        Actions de formations
# 9                          True  Actions de formations,Bilans de compétences
# 10                         True                        Actions de formations
# 11                        False      Actions de formations par apprentissage
# 12                        False                        Actions de formations
# 13                         True                        Actions de formations
# 14                        False  Actions de formations,Bilans de compétences
# 15                        False                        Actions de formations
# 16                         True                        Actions de formations
# 17                         True                        Actions de formations
# 18                         True                        Actions de formations
# 19                         True                        Actions de formations
# 20                         True                        Actions de formations
# 21                         True                        Actions de formations
# 22                         True                        Actions de formations
# 23                        False                        Actions de formations
# 24                        False                        Actions de formations
# 25                         True                        Actions de formations
# 26                         True                        Actions de formations
# 27                         True                        Actions de formations
#
#     random_id
# 0   32.215638
# 1   84.194779
# 2   64.745143
# 3   73.588300
# 4   59.103676
# 5   54.166305
# 6   62.916227
# 7   89.968066
# 8   13.557677
# 9   83.273431
# 10  76.693079
# 11   0.455877
# 12  58.976241
# 13   8.520535
# 14  26.787058
# 15  62.373002
# 16  11.076358
# 17  68.847214
# 18   3.659532
# 19  83.735294
# 20  10.176485
# 21  62.194901
# 22  16.443552
# 23  20.723553
# 24  90.945398
# 25  55.999881
# 26   7.371078
# 27  52.603892
#
# [28 rows x 56 columns]

# %%
import pandas as pd

file_path = 'Les_qualiopi_dans_la_liste_des_entreprises_qui_ont_change_leur_statut.csv'
df = pd.read_csv(file_path)

colonnes_a_conserver = [
    'ID', 'nom', 'Email', 'Crée', 'Mobile', 'Activite1', 'Activite2', 'Activite3', 
    'Adresse', 'CodePostale', 'Ville', 'Siret', 'Statut'
]

df_filtrer = df[colonnes_a_conserver]

df_filtrer['Statut'] = df_filtrer['Statut'].replace('Pas Qualiopi', 'Qualiopi')

df_filtrer.to_csv("Liste_nn_modified.csv", index=False)
df_filtrer
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13304\3935582121.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrer['Statut'] = df_filtrer['Statut'].replace('Pas Qualiopi', 'Qualiopi')
#         ID                                       nom  Email  \
# 0      702                                       A2O    NaN
# 1     4034             AGENCE DE VOYAGES IMAGINAIRES    NaN
# 2    14800                          AUTO ECOLE MITTY    NaN
# 3    15644                         AYALA CONSEILS RH    NaN
# 4    19648                          BOUCHET PHILIPPE    NaN
# 5    21532                     CABINET DE PORT ROYAL    NaN
# 6    26914                            CHILLA FRANCIS    NaN
# 7    30438  CONSEIL ARCHITEC URBANISME ENVIRONNEMENT    NaN
# 8    39228                                   EFFILAB    NaN
# 9    39966                                    ELEVOL    NaN
# 10   43678                            EVOL EDUCATION    NaN
# 11   44422                            FABULOUS.PARIS    NaN
# 12   47326                                  FORMA-PY    NaN
# 13   49958                   GATTINI-LOBSANG VALERIE    NaN
# 14   52902                            GUEGAN CORINNE    NaN
# 15   54390                              HEMIS FR SAS    NaN
# 16   55244                             Horizon Jeune    NaN
# 17   58426         I-NT  CONSEIL ET FORMATION - EURL    NaN
# 18   58556       INTERNATIONAL DEVELOPPEMENT SYSTEME    NaN
# 19   60072                              JC AUTO MOTO    NaN
# 20   69298                         LIESSE AUTO ECOLE    NaN
# 21   69362                  LIGONES-LAFFORT BEATRICE    NaN
# 22   70480                       LOUIS Isabelle (EI)    NaN
# 23  102446                      Mon Analyse Foncière    NaN
# 24  102938                  Monsieur ALAIN GONCALVES    NaN
# 25  123050                                   NEWO RH    NaN
# 26  125670                         OPTIMAL-IT SYSTEM    NaN
# 27  129514           PIERSON DOMINIQUE (DP TRAINING)    NaN
#
#                          Crée  Mobile  \
# 0   2023-06-09T10:32:42+03:00     NaN
# 1   2023-06-09T10:34:56+03:00     NaN
# 2   2023-06-09T10:41:25+03:00     NaN
# 3   2023-06-09T10:41:54+03:00     NaN
# 4   2023-06-09T10:44:15+03:00     NaN
# 5   2023-06-09T11:33:33+03:00     NaN
# 6   2023-06-09T12:12:02+03:00     NaN
# 7   2023-06-09T12:14:31+03:00     NaN
# 8   2023-06-09T12:20:39+03:00     NaN
# 9   2023-06-09T12:21:06+03:00     NaN
# 10  2023-06-09T12:57:58+03:00     NaN
# 11  2023-06-09T12:58:31+03:00     NaN
# 12  2023-06-09T13:00:28+03:00     NaN
# 13  2023-06-09T13:02:04+03:00     NaN
# 14  2023-06-09T13:03:51+03:00     NaN
# 15  2023-06-09T13:04:42+03:00     NaN
# 16  2023-06-09T13:06:09+03:00     NaN
# 17  2023-06-09T13:07:57+03:00     NaN
# 18  2023-06-09T13:08:02+03:00     NaN
# 19  2023-06-09T15:39:20+03:00     NaN
# 20  2023-06-09T15:45:12+03:00     NaN
# 21  2023-06-09T15:45:14+03:00     NaN
# 22  2023-06-09T15:45:53+03:00     NaN
# 23  2023-06-09T16:48:50+03:00     NaN
# 24  2023-06-09T16:49:08+03:00     NaN
# 25  2023-06-09T17:16:12+03:00     NaN
# 26  2023-06-09T17:17:43+03:00     NaN
# 27  2023-06-09T17:19:53+03:00     NaN
#
#                                             Activite1  \
# 0   Développement des capacités d'orientation, d'i...
# 1                          Musique, arts du spectacle
# 2                             Enseignement, formation
# 3   Ressources humaines, gestion du personnel, ges...
# 4                                     Commerce, vente
# 5                                               Santé
# 6   Métallurgie (y compris sidérurgie, fonderie, n...
# 7                          Droit, sciences politiques
# 8       Spécialités plurivalentes de la communication
# 9   Développement des capacités comportementales e...
# 10                                     Travail social
# 11  Coiffure, esthétique et autres spécialités des...
# 12                               Formations générales
# 13                                              Santé
# 14                                                NaN
# 15  Développement des capacités comportementales e...
# 16  Développement des capacités d'orientation, d'i...
# 17  Informatique, traitement de l'information, rés...
# 18                                     Travail social
# 19                            Enseignement, formation
# 20                            Enseignement, formation
# 21  Spécialités plurivalentes des échanges et de l...
# 22                                        Psychologie
# 23                                          Autres...
# 24  Sécurité des biens et des personnes, police, s...
# 25  Ressources humaines, gestion du personnel, ges...
# 26  Documentation, bibliothèques, administration d...
# 27                               Formations générales
#
#                                             Activite2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Sécurité des biens et des personnes, police, s...
# 5                             Enseignement, formation
# 6                              Structures métalliques
# 7                                     Arts plastiques
# 8                                                 NaN
# 9   Développement des capacités individuelles d'or...
# 10                            Enseignement, formation
# 11                                                NaN
# 12         Spécialités concernant plusieurs capacités
# 13       Animation culturelle, sportive et de loisirs
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Développement des capacités comportementales e...
# 22  Ressources humaines, gestion du personnel, ges...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  Informatique, traitement de l'information, rés...
# 27                                    Commerce, vente
#
#                                             Activite3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Développement des capacités comportementales e...
# 5                                                 NaN
# 6                                                 NaN
# 7                                 Bâtiment: finitions
# 8                                                 NaN
# 9   Développement des capacités d'orientation, d'i...
# 10       Animation culturelle, sportive et de loisirs
# 11                                                NaN
# 12                                                NaN
# 13                                Pratiques sportives
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                              Santé
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                              Comptabilité, gestion
#
#                                    Adresse  CodePostale                 Ville  \
# 0                          140 RUE DE LORS      87380.0               GLANGES
# 1                                      NaN          NaN                   NaN
# 2                              1 AV DE BRY      94170.0  LE PERREUX SUR MARNE
# 3                                      NaN          NaN                   NaN
# 4                                      NaN          NaN                   NaN
# 5                                      NaN          NaN                   NaN
# 6                  64 BIS ROUTE DE LOURDES      65290.0               JUILLAN
# 7                    26 PL VINCENT RASPAIL      83000.0                TOULON
# 8                                      NaN          NaN                   NaN
# 9                                      NaN          NaN                   NaN
# 10            36 RUE BOCQUET FLOCHEL BP 40      62000.0                 ARRAS
# 11                                     NaN          NaN                   NaN
# 12                                     NaN          NaN                   NaN
# 13                2690, route des Amerands      74170.0  ST GERVAIS LES BAINS
# 14                                     NaN          NaN                   NaN
# 15                                     NaN          NaN                   NaN
# 16                   14 C RUE DES FUSILLES      23200.0              AUBUSSON
# 17                     07 RUE DES FOUGERES      37420.0            RIGNY USSE
# 18     292 RUE CAMILLE GUERIN ST SO BAZAAR      59000.0                 LILLE
# 19                 8 QUAI DE LA REPUBLIQUE      17100.0               SAINTES
# 20                16 RUE DU CHAMP GAILLARD      95310.0      ST OUEN L AUMONE
# 21  CHALLENGE INNOVATION 7 RUE DE LA SERRE      31490.0              LEGUEVIN
# 22                  16 rue des flots bleus      56270.0              PLOEMEUR
# 23                                     NaN          NaN                   NaN
# 24                                     NaN          NaN                   NaN
# 25                   65 AV DE LA BRASSERIE      33260.0      LA TESTE DE BUCH
# 26                     19 RTE DE BESSIERES      31240.0               L UNION
# 27                             36 RUE CLER      75007.0              PARIS 07
#
#              Siret    Statut
# 0   81063315600015  Qualiopi
# 1   50048925700039  Qualiopi
# 2   88965325900024  Qualiopi
# 3   81995878600025  Qualiopi
# 4   43846427300053  Qualiopi
# 5   53029712600019  Qualiopi
# 6   41107875100053  Qualiopi
# 7   33078341600051  Qualiopi
# 8   53120556500066  Qualiopi
# 9   82969180700012  Qualiopi
# 10  88880182600015  Qualiopi
# 11  90185557700010  Qualiopi
# 12  92240663200013  Qualiopi
# 13  50216291000033  Qualiopi
# 14  88797873200014  Qualiopi
# 15  79515705600016  Qualiopi
# 16  77797574900014  Qualiopi
# 17  79767120300017  Qualiopi
# 18  45317411200061  Qualiopi
# 19  83519216200013  Qualiopi
# 20  82346816000010  Qualiopi
# 21  50741160100010  Qualiopi
# 22  90459731700026  Qualiopi
# 23  38857545800053  Qualiopi
# 24  83309144000028  Qualiopi
# 25  91890993800014  Qualiopi
# 26  80467865400026  Qualiopi
# 27  44922655400060  Qualiopi

# %%
import time
import configparser
import requests
import pandas as pd

def CrmBitrix(content='', params=[], result='', pause_duration=1, max_retries=3):
    print("Début de la récupération des données de Bitrix24...")
    
    config = configparser.ConfigParser()
    config.read('config.ini')

    if 'BITRIX' not in config:
        raise ValueError('Section BITRIX manquante dans le fichier \'config.ini\'')

    BITRIX_DOMAIN = config.get('BITRIX', 'BITRIX_DOMAIN')
    BITRIX_TOKEN = config.get('BITRIX', 'BITRIX_TOKEN')

    if not BITRIX_DOMAIN or not BITRIX_TOKEN:
        raise ValueError('Domaine et/ou token Bitrix manquants dans le fichier \'config.ini\'')

    print(f"Utilisation du domaine Bitrix: {BITRIX_DOMAIN}")

    params_str = '&'.join(params)
    BitrixUrl = f'https://{BITRIX_DOMAIN}/rest/1/{BITRIX_TOKEN}/{content}?{params_str}&start='
    
    listNoms, listIds = [], []

    start = 0
    while True:
        url = BitrixUrl + str(start)
        print(f"Envoi de la requête à l'URL: {url}")
        
        for attempt in range(max_retries):
            try:
                response = requests.get(url)
                response.raise_for_status()
                break
            except requests.exceptions.HTTPError as e:
                if response.status_code == 429:
                    wait_time = pause_duration * (2 ** attempt)
                    print(f'Limite de taux dépassée. Nouvelle tentative dans {wait_time} secondes...')
                    time.sleep(wait_time)
                else:
                    raise ValueError(f'Erreur lors de la récupération depuis Bitrix : {e}')
            except requests.exceptions.RequestException as e:
                raise ValueError(f'Erreur lors de la récupération depuis Bitrix : {e}')

        data = response.json()
        if 'result' in data:
            contacts = data['result']
            print(f"Nombre de contacts récupérés: {len(contacts)}")
            for contact in contacts:
                if result == 'title': 
                    listNoms.append(contact.get('TITLE', ''))
                    listIds.append(contact.get('ID', ''))
                else:
                    return 'Erreur avec les données attendues. Merci de vérifier la variable \'result\'.'

        if 'next' in data:
            start = data['next']
        else:
            break

    if result == 'title':
        df_btx = pd.DataFrame({'ID': listIds, 'nom': listNoms})
    else:
        return 'Erreur avec les données attendues. Merci de vérifier la variable \'result\'.'

    print("Récupération des données de Bitrix24 terminée.")
    return df_btx

def get_statut_value(statut):
    statut_mapping = {
        'Pas qualiopi': '140',
        'Qaliopi': '142',
        'Qaliopi à jour': '144',
        'Qaliopi perdu':'146'
    }
    return statut_mapping.get(statut, '142') 

def update_bitrix_status(df_local, df_bitrix):
    print("Début de la mise à jour des statuts dans Bitrix24...")

    config = configparser.ConfigParser()
    config.read('config.ini')

    BITRIX_DOMAIN = config.get('BITRIX', 'BITRIX_DOMAIN')
    BITRIX_TOKEN = config.get('BITRIX', 'BITRIX_TOKEN')

    if not BITRIX_DOMAIN or not BITRIX_TOKEN:
        raise ValueError('Domaine et/ou token Bitrix manquants dans le fichier \'config.ini\'')

    for index, row in df_local.iterrows():
        nom = row['nom']
        statut = row['Statut']
        
        print(f"Vérification du nom: {nom} avec statut: {statut}")
        
        match = df_bitrix[df_bitrix['nom'] == nom]
        if not match.empty:
            bitrix_id = match.iloc[0]['ID']
            statut_value = get_statut_value(statut)
            update_url = f'https://{BITRIX_DOMAIN}/rest/1/{BITRIX_TOKEN}/crm.company.update.json'
            data = {
                'ID': bitrix_id,
                'fields': {
                    'UF_CRM_1722346888': statut_value
                }
            }
            print(f"Envoi de la mise à jour pour l'ID Bitrix: {bitrix_id} avec statut: {statut_value}")
            response = requests.post(update_url, json=data)
            if response.status_code == 200:
                print(f'Statut mis à jour avec succès pour {nom} dans Bitrix24')
            else:
                print(f'Échec de la mise à jour du statut pour {nom} dans Bitrix24')

input_csv = 'Liste_nn_modified.csv'

print("Chargement du fichier CSV local...")
df_local = pd.read_csv(input_csv, low_memory=False)

print(df_local.head())
print(f"Nombre total de lignes dans le fichier local: {len(df_local)}")

df_btx = CrmBitrix(
    content='crm.company.list.json',
    params=[
        'select[]=ID',
        'select[]=TITLE'
    ],
    result="title"
)

update_bitrix_status(df_local, df_btx)

print("Mise à jour des statuts terminée.")
# Out:
# Chargement du fichier CSV local...
#       ID                            nom  Email                       Crée  \
# 0    702                            A2O    NaN  2023-06-09T10:32:42+03:00
# 1   4034  AGENCE DE VOYAGES IMAGINAIRES    NaN  2023-06-09T10:34:56+03:00
# 2  14800               AUTO ECOLE MITTY    NaN  2023-06-09T10:41:25+03:00
# 3  15644              AYALA CONSEILS RH    NaN  2023-06-09T10:41:54+03:00
# 4  19648               BOUCHET PHILIPPE    NaN  2023-06-09T10:44:15+03:00
#
#    Mobile                                          Activite1  \
# 0     NaN  Développement des capacités d'orientation, d'i...
# 1     NaN                         Musique, arts du spectacle
# 2     NaN                            Enseignement, formation
# 3     NaN  Ressources humaines, gestion du personnel, ges...
# 4     NaN                                    Commerce, vente
#
#                                            Activite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Sécurité des biens et des personnes, police, s...
#
#                                            Activite3          Adresse  \
# 0                                                NaN  140 RUE DE LORS
# 1                                                NaN              NaN
# 2                                                NaN      1 AV DE BRY
# 3                                                NaN              NaN
# 4  Développement des capacités comportementales e...              NaN
#
#    CodePostale                 Ville           Siret    Statut
# 0      87380.0               GLANGES  81063315600015  Qualiopi
# 1          NaN                   NaN  50048925700039  Qualiopi
# 2      94170.0  LE PERREUX SUR MARNE  88965325900024  Qualiopi
# 3          NaN                   NaN  81995878600025  Qualiopi
# 4          NaN                   NaN  43846427300053  Qualiopi
# Nombre total de lignes dans le fichier local: 28
# Début de la récupération des données de Bitrix24...
# Utilisation du domaine Bitrix: yav.bitrix24.fr
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=0
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=50
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13400
# Nombre de contacts récupérés: 50
# ...
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=40950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=41950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=42950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=43000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=43050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=43100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=43150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=43200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=43250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=43300
# Nombre de contacts récupérés: 24
# Récupération des données de Bitrix24 terminée.
# Début de la mise à jour des statuts dans Bitrix24...
# Vérification du nom: A2O avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 702 avec statut: 142
# Statut mis à jour avec succès pour A2O dans Bitrix24
# Vérification du nom: AGENCE DE VOYAGES IMAGINAIRES avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 4034 avec statut: 142
# Statut mis à jour avec succès pour AGENCE DE VOYAGES IMAGINAIRES dans Bitrix24
# Vérification du nom: AUTO ECOLE MITTY avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 14800 avec statut: 142
# Statut mis à jour avec succès pour AUTO ECOLE MITTY dans Bitrix24
# Vérification du nom: AYALA CONSEILS RH avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 15644 avec statut: 142
# Statut mis à jour avec succès pour AYALA CONSEILS RH dans Bitrix24
# Vérification du nom: BOUCHET PHILIPPE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 19648 avec statut: 142
# Statut mis à jour avec succès pour BOUCHET PHILIPPE dans Bitrix24
# Vérification du nom: CABINET DE PORT ROYAL avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 21532 avec statut: 142
# Statut mis à jour avec succès pour CABINET DE PORT ROYAL dans Bitrix24
# Vérification du nom: CHILLA FRANCIS avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 26914 avec statut: 142
# Statut mis à jour avec succès pour CHILLA FRANCIS dans Bitrix24
# Vérification du nom: CONSEIL ARCHITEC URBANISME ENVIRONNEMENT avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 30438 avec statut: 142
# Statut mis à jour avec succès pour CONSEIL ARCHITEC URBANISME ENVIRONNEMENT dans Bitrix24
# Vérification du nom: EFFILAB avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 39228 avec statut: 142
# Statut mis à jour avec succès pour EFFILAB dans Bitrix24
# Vérification du nom: ELEVOL avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 39966 avec statut: 142
# Statut mis à jour avec succès pour ELEVOL dans Bitrix24
# Vérification du nom: EVOL EDUCATION avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 43678 avec statut: 142
# Statut mis à jour avec succès pour EVOL EDUCATION dans Bitrix24
# Vérification du nom: FABULOUS.PARIS avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 44422 avec statut: 142
# Statut mis à jour avec succès pour FABULOUS.PARIS dans Bitrix24
# Vérification du nom: FORMA-PY avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 47326 avec statut: 142
# Statut mis à jour avec succès pour FORMA-PY dans Bitrix24
# Vérification du nom: GATTINI-LOBSANG VALERIE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 49958 avec statut: 142
# Statut mis à jour avec succès pour GATTINI-LOBSANG VALERIE dans Bitrix24
# Vérification du nom: GUEGAN CORINNE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 52902 avec statut: 142
# Statut mis à jour avec succès pour GUEGAN CORINNE dans Bitrix24
# Vérification du nom: HEMIS FR SAS avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 54390 avec statut: 142
# Statut mis à jour avec succès pour HEMIS FR SAS dans Bitrix24
# Vérification du nom: Horizon Jeune avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 55244 avec statut: 142
# Statut mis à jour avec succès pour Horizon Jeune dans Bitrix24
# Vérification du nom: I-NT  CONSEIL ET FORMATION - EURL avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 58426 avec statut: 142
# Statut mis à jour avec succès pour I-NT  CONSEIL ET FORMATION - EURL dans Bitrix24
# Vérification du nom: INTERNATIONAL DEVELOPPEMENT SYSTEME avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 58556 avec statut: 142
# Statut mis à jour avec succès pour INTERNATIONAL DEVELOPPEMENT SYSTEME dans Bitrix24
# Vérification du nom: JC AUTO MOTO avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 60072 avec statut: 142
# Statut mis à jour avec succès pour JC AUTO MOTO dans Bitrix24
# Vérification du nom: LIESSE AUTO ECOLE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 69298 avec statut: 142
# Statut mis à jour avec succès pour LIESSE AUTO ECOLE dans Bitrix24
# Vérification du nom: LIGONES-LAFFORT BEATRICE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 69362 avec statut: 142
# Statut mis à jour avec succès pour LIGONES-LAFFORT BEATRICE dans Bitrix24
# Vérification du nom: LOUIS Isabelle (EI) avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 70480 avec statut: 142
# Statut mis à jour avec succès pour LOUIS Isabelle (EI) dans Bitrix24
# Vérification du nom: Mon Analyse Foncière avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 102446 avec statut: 142
# Statut mis à jour avec succès pour Mon Analyse Foncière dans Bitrix24
# Vérification du nom: Monsieur ALAIN GONCALVES avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 102938 avec statut: 142
# Statut mis à jour avec succès pour Monsieur ALAIN GONCALVES dans Bitrix24
# Vérification du nom: NEWO RH avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 123050 avec statut: 142
# Statut mis à jour avec succès pour NEWO RH dans Bitrix24
# Vérification du nom: OPTIMAL-IT SYSTEM avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 125670 avec statut: 142
# Statut mis à jour avec succès pour OPTIMAL-IT SYSTEM dans Bitrix24
# Vérification du nom: PIERSON DOMINIQUE (DP TRAINING) avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 129514 avec statut: 142
# Statut mis à jour avec succès pour PIERSON DOMINIQUE (DP TRAINING) dans Bitrix24
# Mise à jour des statuts terminée.

# %%
import pandas as pd

file1_path = 'df_filtre_Non_Matching_Siret_YAV_Results.csv'
file2_path = 'listesdesqualiopietnon.csv'

try:
    companyyav_df = pd.read_csv(file1_path)
    all_records_export_df = pd.read_csv(file2_path, delimiter=',', on_bad_lines='skip', low_memory=False)
except pd.errors.ParserError as e:
    print(f"Erreur lors de la lecture des fichiers CSV : {e}")

if 'companyyav_df' in locals() and 'all_records_export_df' in locals():
    print("Colonnes disponibles dans 'listesdesqualiopietnon.csv' :")
    print(all_records_export_df.columns)

    if 'siretetablissementdeclarant' in all_records_export_df.columns:

        companyyav_df['Siret'] = companyyav_df['Siret'].astype(str).str.replace(r'\.0$', '', regex=True).str.strip()
        all_records_export_df['siretetablissementdeclarant'] = all_records_export_df['siretetablissementdeclarant'].astype(str).str.strip()

        missing_siret_in_all_records = companyyav_df[~companyyav_df['Siret'].isin(all_records_export_df['siretetablissementdeclarant'])]

        print(f"Nombre de SIRET dans 'companyyav.csv' qui ne se trouvent pas dans 'listesdesqualiopietnon.csv': {missing_siret_in_all_records.shape[0]}")

        print("Liste des SIRET manquants :")
        print(missing_siret_in_all_records['Siret'].tolist())
    else:
        print("La colonne 'siretetablissementdeclarant' n'existe pas dans le fichier 'listesdesqualiopietnon.csv'.")
else:
    print("Les fichiers n'ont pas pu être chargés correctement.")
# Out:
# Colonnes disponibles dans 'listesdesqualiopietnon.csv' :
# Index(['numerodeclarationactivite', 'numerosdeclarationactiviteprecedent',
#        'denomination', 'siren', 'siretetablissementdeclarant',
#        'adressephysiqueorganismeformation_voie',
#        'adressephysiqueorganismeformation_codepostal',
#        'adressephysiqueorganismeformation_ville',
#        'adressephysiqueorganismeformation_coderegion', 'geocodageban',
#        'certifications_actionsdeformation',
#        'certifications_bilansdecompetences', 'certifications_vae',
#        'certifications_actionsdeformationparapprentissage',
#        'organismeetrangerrepresente_denomination',
#        'organismeetrangerrepresente_voie',
#        'organismeetrangerrepresente_codepostal',
#        'organismeetrangerrepresente_ville', 'organismeetrangerrepresente_pays',
#        'informationsdeclarees_datedernieredeclaration',
#        'informationsdeclarees_debutexercice',
#        'informationsdeclarees_finexercice',
#        'informationsdeclarees_specialitesdeformation_codespecialite1',
#        'informationsdeclarees_specialitesdeformation_libellespecialite1',
#        'informationsdeclarees_specialitesdeformation_codespecialite2',
#        'informationsdeclarees_specialitesdeformation_libellespecialite2',
#        'informationsdeclarees_specialitesdeformation_codespecialite3',
#        'informationsdeclarees_specialitesdeformation_libellespecialite3',
#        'informationsdeclarees_nbstagiaires',
#        'informationsdeclarees_nbstagiairesconfiesparunautreof',
#        'informationsdeclarees_effectifformateurs', 'com_arm_code',
#        'com_arm_name', 'epci_code', 'epci_name', 'dep_code', 'dep_name',
#        'reg_name', 'reg_code', 'toutes_specialites',
#        'organisme_formation_geocode', 'certifications', 'random_id'],
#       dtype='object')
# Nombre de SIRET dans 'companyyav.csv' qui ne se trouvent pas dans 'listesdesqualiopietnon.csv': 445
# Liste des SIRET manquants :
# ['50316997100010', '85297199300021', '52340659300021', '84931718500015', '32890745600029', '82849341100015', '79927850200015', '90171320600018', '84438687000027', '50873843200014', '50900850400029', '83192856900027', '91164256900014', '84383347600016', '83107750800024', '52137131000025', '82456145000019', '84204588200029', '78963006800011', '83366907000017', '52288639900016', '82186178800015', '84264736400020', '40162927400044', '90059673500010', '90058808800014', '51824475100039', '89032259700018', '84906323500014', '89527698800014', '84129469700013', '53486453300011', '92151995500014', '80144090000018', '83394000000015', '75357356700033', '80827316300028', '88355157400014', '79405679600020', '83256511300012', '87851373800012', '84311417400017', '79112367200036', '85179594800013', '44431840600014', '83856212200013', '81038029500016', '48426698600013', '89831990000012', '83291768600012', '89178556000014', '80422939100029', '32469563400059', '37945849000081', '52367466100039', '88828872700017', '90482112100012', '53471566900014', '32687563000013', '80441678200014', '45156450400020', '41060518200022', '31464880900023', '79070767300055', '50827508800013', '40816462200040', '81279551600010', '90085301100014', '85880005500015', '81085954600022', '82862787700016', '53046414800028', '45078920100065', '51276372300032', '83961802200017', '43906005400020', '43501065700094', '90504963100013', '53969993400029', '89203079200014', '89986143900011', '41772755900037', '47797683100016', '52970911500016', '38916232200025', '50092347900017', '53899838600030', '88791487700014', '51360518800020', '38410807200032', '80263528400036', '53812167400021', '81886048800019', '41291216400057', '84348018700015', '79281992200016', '44128728100048', '85327405800017', '51832854700014', '52089898200068', '90439995300010', '88832899400015', '49128675300042', '88810229000010', '82026375400021', '52161465100011', '91259389400013', '91771869400016', '50928323000019', '88864889600015', '52273422700013', '44110545900065', '88473850100011', '44009702000042', '52233948000025', '89530725400014', '83225378500014', '38770710200019', '39526135700010', '79778022800012', '50152750100016', '41517481200032', '88387366300016', '51349908700031', '45243909400031', '53923523400066', '40345225300020', '49814542400020', '91060310900018', '80995873900017', '80080009600029', '85128186500010', '90972743000011', '13002016700065', '43367640000057', '44303008500023', '88538476800010', '81359766300042', '52410603600022', '83354615300010', '87831604100010', '44379371600046', '35113629600024', '84801453600025', '31008369600032', '84005364900033', '50457687700030', '43980722300045', '52775936900020', '81169623600017', '81803135300027', '75323156200020', '53413018200049', '85367282200014', '82746814100037', '88979292500014', '42403261300012', '81965124100013', '40338824200063', '82435425200010', '79939555300016', '81793838400010', '85409741700026', '85320470900028', '82279838500032', '43268286200037', '92077266200010', '80016890800013', '49503775600014', '41488463500049', '50289734100017', '90513740200012', '90926922700015', '42032593800033', '84538871900013', '48035599900016', '49347830900021', '88093092000017', '48243216800011', '87755278600015', '40189605500050', '79310727700030', '80455617300016', '85386605100016', '33262941900067', '87840853300015', '45188099100018', '50250587800020', '39346577800073', '81200141000024', '33761951400033', '88399165500019', '80974112700041', '51503352000047', '83801417300010', '90312640700019', '32768973300027', '80910383100040', '79058997200039', '80802754400044', '83893797700018', '91482765400015', '83113579300014', '75044522300035', '84788938300034', '81221015100021', '44325924700023', '79495947800031', '89060668400011', '44781759400024', '90123051600014', '32593111100018', '79448667000035', '51329533700028', '91150710100010', '85339635600018', '82958679100024', '39157976000037', '44030584500032', '51914703700013', '44224542900059', '33862942100011', '82 ...

# %%
missing_siret_in_all_records.to_csv("Liste_des_entreprises_qui_ont_change_de_statut_et_qui_ne_se_trouve_dans_dgefp.csv", index=False)
missing_siret_in_all_records
# Out:
#          ID                                               nom Email  \
# 1       760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN   NaN
# 2       968                             ABConsultant & Net Oi   NaN
# 3      1094                                      AB FORMATION   NaN
# 4      1568                                            ACCEVA   NaN
# 5      1584                        ACCIOR LES SABLES D'OLONNE   NaN
# ..      ...                                               ...   ...
# 467  129244                                     PIAU MATHILDE   NaN
# 468  129254                                  PICANTIN Olivier   NaN
# 470  129972                                PLUMES DE CIGOGNES   NaN
# 471  130040                                    PMO SUSTAINING   NaN
# 472  131138                                 PRO ARTE GRAPHICA   NaN
#
#                           Crée  Mobile  \
# 1    2023-06-09T10:32:45+03:00     NaN
# 2    2023-06-09T10:32:53+03:00     NaN
# 3    2023-06-09T10:32:58+03:00     NaN
# 4    2023-06-09T10:33:18+03:00     NaN
# 5    2023-06-09T10:33:18+03:00     NaN
# ..                         ...     ...
# 467  2023-06-09T17:19:44+03:00     NaN
# 468  2023-06-09T17:19:45+03:00     NaN
# 470  2023-06-09T17:20:09+03:00     NaN
# 471  2023-06-09T17:20:12+03:00     NaN
# 472  2023-06-09T17:20:49+03:00     NaN
#
#                                              Activite1  \
# 1                                 Formations générales
# 2                                      Commerce, vente
# 3                                Comptabilité, gestion
# 4                                       Travail social
# 5                                Comptabilité, gestion
# ..                                                 ...
# 467                               Formations générales
# 468                                                NaN
# 470               Bâtiment: construction et couverture
# 471           Technologies industrielles fondamentales
# 472  Autres disciplines artistiques et spécialités ...
#
#                                              Activite2 Activite3  \
# 1                                            Autres...       NaN
# 2    Ressources humaines, gestion du personnel, ges...       NaN
# 3                                                  NaN       NaN
# 4                              Enseignement, formation       NaN
# 5    Ressources humaines, gestion du personnel, ges...       NaN
# ..                                                 ...       ...
# 467                                                NaN       NaN
# 468                                                NaN       NaN
# 470  Sécurité des biens et des personnes, police, s...       NaN
# 471                                                NaN       NaN
# 472         Techniques de l'imprimerie et de l'édition       NaN
#
#                           Adresse  CodePostale                  Ville  \
# 1           29 RUE ROMAIN ROLLAND      44100.0                 NANTES
# 2                             NaN          NaN                    NaN
# 3    27 CHEMIN DE LA CAVERNE N°17      97434.0                ST PAUL
# 4                             NaN          NaN                    NaN
# 5                             NaN          NaN                    NaN
# ..                            ...          ...                    ...
# 467                           NaN          NaN                    NaN
# 468                           NaN          NaN                    NaN
# 470           10 RUE DES CIGOGNES      97480.0              ST JOSEPH
# 471            1 CHEMIN DE L'ONDE      44240.0  LA CHAPELLE SUR ERDRE
# 472          24, quai de la Fosse      44000.0                 NANTES
#
#               Siret        Statut
# 1    50316997100010  Pas Qualiopi
# 2    85297199300021  Pas Qualiopi
# 3    52340659300021  Pas Qualiopi
# 4    84931718500015  Pas Qualiopi
# 5    32890745600029  Pas Qualiopi
# ..              ...           ...
# 467  88020025800015  Pas Qualiopi
# 468  85205528400016  Pas Qualiopi
# 470  91812767100017  Pas Qualiopi
# 471  52338497200023  Pas Qualiopi
# 472  33864179800016  Pas Qualiopi
#
# [445 rows x 13 columns]

# %%
import pandas as pd

file_path = 'Liste_des_entreprises_qui_ont_change_de_statut_et_qui_ne_se_trouve_dans_dgefp.csv'
df = pd.read_csv(file_path)

colonnes_a_conserver = [
    'ID', 'nom', 'Email', 'Crée', 'Mobile', 'Activite1', 'Activite2', 'Activite3', 
    'Adresse', 'CodePostale', 'Ville', 'Siret', 'Statut'
]

df_filtrers = df[colonnes_a_conserver]

df_filtrers['Statut'] = df_filtrers['Statut'].replace('Pas Qualiopi', 'Qualiopi')

df_filtrers.to_csv("Liste_ferme_modified.csv", index=False)
df_filtrers
# Out:
#          ID                                               nom Email  \
# 0       760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN   NaN
# 1       968                             ABConsultant & Net Oi   NaN
# 2      1094                                      AB FORMATION   NaN
# 3      1568                                            ACCEVA   NaN
# 4      1584                        ACCIOR LES SABLES D'OLONNE   NaN
# ..      ...                                               ...   ...
# 440  129244                                     PIAU MATHILDE   NaN
# 441  129254                                  PICANTIN Olivier   NaN
# 442  129972                                PLUMES DE CIGOGNES   NaN
# 443  130040                                    PMO SUSTAINING   NaN
# 444  131138                                 PRO ARTE GRAPHICA   NaN
#
#                           Crée  Mobile  \
# 0    2023-06-09T10:32:45+03:00     NaN
# 1    2023-06-09T10:32:53+03:00     NaN
# 2    2023-06-09T10:32:58+03:00     NaN
# 3    2023-06-09T10:33:18+03:00     NaN
# 4    2023-06-09T10:33:18+03:00     NaN
# ..                         ...     ...
# 440  2023-06-09T17:19:44+03:00     NaN
# 441  2023-06-09T17:19:45+03:00     NaN
# 442  2023-06-09T17:20:09+03:00     NaN
# 443  2023-06-09T17:20:12+03:00     NaN
# 444  2023-06-09T17:20:49+03:00     NaN
#
#                                              Activite1  \
# 0                                 Formations générales
# 1                                      Commerce, vente
# 2                                Comptabilité, gestion
# 3                                       Travail social
# 4                                Comptabilité, gestion
# ..                                                 ...
# 440                               Formations générales
# 441                                                NaN
# 442               Bâtiment: construction et couverture
# 443           Technologies industrielles fondamentales
# 444  Autres disciplines artistiques et spécialités ...
#
#                                              Activite2 Activite3  \
# 0                                            Autres...       NaN
# 1    Ressources humaines, gestion du personnel, ges...       NaN
# 2                                                  NaN       NaN
# 3                              Enseignement, formation       NaN
# 4    Ressources humaines, gestion du personnel, ges...       NaN
# ..                                                 ...       ...
# 440                                                NaN       NaN
# 441                                                NaN       NaN
# 442  Sécurité des biens et des personnes, police, s...       NaN
# 443                                                NaN       NaN
# 444         Techniques de l'imprimerie et de l'édition       NaN
#
#                           Adresse  CodePostale                  Ville  \
# 0           29 RUE ROMAIN ROLLAND      44100.0                 NANTES
# 1                             NaN          NaN                    NaN
# 2    27 CHEMIN DE LA CAVERNE N°17      97434.0                ST PAUL
# 3                             NaN          NaN                    NaN
# 4                             NaN          NaN                    NaN
# ..                            ...          ...                    ...
# 440                           NaN          NaN                    NaN
# 441                           NaN          NaN                    NaN
# 442           10 RUE DES CIGOGNES      97480.0              ST JOSEPH
# 443            1 CHEMIN DE L'ONDE      44240.0  LA CHAPELLE SUR ERDRE
# 444          24, quai de la Fosse      44000.0                 NANTES
#
#               Siret    Statut
# 0    50316997100010  Qualiopi
# 1    85297199300021  Qualiopi
# 2    52340659300021  Qualiopi
# 3    84931718500015  Qualiopi
# 4    32890745600029  Qualiopi
# ..              ...       ...
# 440  88020025800015  Qualiopi
# 441  85205528400016  Qualiopi
# 442  91812767100017  Qualiopi
# 443  52338497200023  Qualiopi
# 444  33864179800016  Qualiopi
#
# [445 rows x 13 columns]

# %%
import time
import configparser
import requests
import pandas as pd

def CrmBitrix(content='', params=[], result='', pause_duration=1, max_retries=3):
    print("Début de la récupération des données de Bitrix24...")
    
    config = configparser.ConfigParser()
    config.read('config.ini')

    if 'BITRIX' not in config:
        raise ValueError('Section BITRIX manquante dans le fichier \'config.ini\'')

    BITRIX_DOMAIN = config.get('BITRIX', 'BITRIX_DOMAIN')
    BITRIX_TOKEN = config.get('BITRIX', 'BITRIX_TOKEN')

    if not BITRIX_DOMAIN or not BITRIX_TOKEN:
        raise ValueError('Domaine et/ou token Bitrix manquants dans le fichier \'config.ini\'')

    print(f"Utilisation du domaine Bitrix: {BITRIX_DOMAIN}")

    params_str = '&'.join(params)
    BitrixUrl = f'https://{BITRIX_DOMAIN}/rest/1/{BITRIX_TOKEN}/{content}?{params_str}&start='
    
    listNoms, listIds = [], []

    start = 0
    while True:
        url = BitrixUrl + str(start)
        print(f"Envoi de la requête à l'URL: {url}")
        
        for attempt in range(max_retries):
            try:
                response = requests.get(url)
                response.raise_for_status()
                break
            except requests.exceptions.HTTPError as e:
                if response.status_code == 429:
                    wait_time = pause_duration * (2 ** attempt)
                    print(f'Limite de taux dépassée. Nouvelle tentative dans {wait_time} secondes...')
                    time.sleep(wait_time)
                else:
                    raise ValueError(f'Erreur lors de la récupération depuis Bitrix : {e}')
            except requests.exceptions.RequestException as e:
                raise ValueError(f'Erreur lors de la récupération depuis Bitrix : {e}')

        data = response.json()
        if 'result' in data:
            contacts = data['result']
            print(f"Nombre de contacts récupérés: {len(contacts)}")
            for contact in contacts:
                if result == 'title': 
                    listNoms.append(contact.get('TITLE', ''))
                    listIds.append(contact.get('ID', ''))
                else:
                    return 'Erreur avec les données attendues. Merci de vérifier la variable \'result\'.'

        if 'next' in data:
            start = data['next']
        else:
            break

    if result == 'title':
        df_btx = pd.DataFrame({'ID': listIds, 'nom': listNoms})
    else:
        return 'Erreur avec les données attendues. Merci de vérifier la variable \'result\'.'

    print("Récupération des données de Bitrix24 terminée.")
    return df_btx

def get_statut_value(statut):
    statut_mapping = {
        'Pas qualiopi': '140',
        'Qaliopi': '142',
        'Qaliopi à jour': '144',
        'Qaliopi perdu':'146'
    }
    return statut_mapping.get(statut, '146') 

def update_bitrix_status(df_local, df_bitrix):
    print("Début de la mise à jour des statuts dans Bitrix24...")

    config = configparser.ConfigParser()
    config.read('config.ini')

    BITRIX_DOMAIN = config.get('BITRIX', 'BITRIX_DOMAIN')
    BITRIX_TOKEN = config.get('BITRIX', 'BITRIX_TOKEN')

    if not BITRIX_DOMAIN or not BITRIX_TOKEN:
        raise ValueError('Domaine et/ou token Bitrix manquants dans le fichier \'config.ini\'')

    for index, row in df_local.iterrows():
        nom = row['nom']
        statut = row['Statut']
        
        print(f"Vérification du nom: {nom} avec statut: {statut}")
        
        match = df_bitrix[df_bitrix['nom'] == nom]
        if not match.empty:
            bitrix_id = match.iloc[0]['ID']
            statut_value = get_statut_value(statut)
            update_url = f'https://{BITRIX_DOMAIN}/rest/1/{BITRIX_TOKEN}/crm.company.update.json'
            data = {
                'ID': bitrix_id,
                'fields': {
                    'UF_CRM_1722346888': statut_value
                }
            }
            print(f"Envoi de la mise à jour pour l'ID Bitrix: {bitrix_id} avec statut: {statut_value}")
            response = requests.post(update_url, json=data)
            if response.status_code == 200:
                print(f'Statut mis à jour avec succès pour {nom} dans Bitrix24')
            else:
                print(f'Échec de la mise à jour du statut pour {nom} dans Bitrix24')

input_csv = 'Liste_ferme_modified.csv'

print("Chargement du fichier CSV local...")
df_local = pd.read_csv(input_csv, low_memory=False)

print(df_local.head())
print(f"Nombre total de lignes dans le fichier local: {len(df_local)}")

df_btx = CrmBitrix(
    content='crm.company.list.json',
    params=[
        'select[]=ID',
        'select[]=TITLE'
    ],
    result="title"
)

update_bitrix_status(df_local, df_btx)

print("Mise à jour des statuts terminée.")
# Out:
# Chargement du fichier CSV local...
#      ID                                               nom Email  \
# 0   760  AADH ACTION ACCOMPAGNEMENTS DEVELOPPEMENT HUMAIN   NaN
# 1   968                             ABConsultant & Net Oi   NaN
# 2  1094                                      AB FORMATION   NaN
# 3  1568                                            ACCEVA   NaN
# 4  1584                        ACCIOR LES SABLES D'OLONNE   NaN
#
#                         Crée  Mobile              Activite1  \
# 0  2023-06-09T10:32:45+03:00     NaN   Formations générales
# 1  2023-06-09T10:32:53+03:00     NaN        Commerce, vente
# 2  2023-06-09T10:32:58+03:00     NaN  Comptabilité, gestion
# 3  2023-06-09T10:33:18+03:00     NaN         Travail social
# 4  2023-06-09T10:33:18+03:00     NaN  Comptabilité, gestion
#
#                                            Activite2 Activite3  \
# 0                                          Autres...       NaN
# 1  Ressources humaines, gestion du personnel, ges...       NaN
# 2                                                NaN       NaN
# 3                            Enseignement, formation       NaN
# 4  Ressources humaines, gestion du personnel, ges...       NaN
#
#                         Adresse  CodePostale    Ville           Siret  \
# 0         29 RUE ROMAIN ROLLAND      44100.0   NANTES  50316997100010
# 1                           NaN          NaN      NaN  85297199300021
# 2  27 CHEMIN DE LA CAVERNE N°17      97434.0  ST PAUL  52340659300021
# 3                           NaN          NaN      NaN  84931718500015
# 4                           NaN          NaN      NaN  32890745600029
#
#      Statut
# 0  Qualiopi
# 1  Qualiopi
# 2  Qualiopi
# 3  Qualiopi
# 4  Qualiopi
# Nombre total de lignes dans le fichier local: 445
# Début de la récupération des données de Bitrix24...
# Utilisation du domaine Bitrix: yav.bitrix24.fr
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=0
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=50
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=1950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=2950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=3950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=4950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=5950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=6950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=7950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=8950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=9950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=10950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=11950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12500
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12550
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12600
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12650
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12700
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12750
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12800
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12850
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12900
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=12950
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13000
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13050
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13100
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13150
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13200
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13250
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13300
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13350
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13400
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13450
# Nombre de contacts récupérés: 50
# Envoi de la requête à l'URL: https://yav.bitrix24.fr/rest/1/m13iijnhd3blq35m/crm.company.list.json?select[]=ID&select[]=TITLE&start=13500
# ...
# Envoi de la mise à jour pour l'ID Bitrix: 111288 avec statut: 146
# Statut mis à jour avec succès pour Monsieur JORDAN GUICHARD dans Bitrix24
# Vérification du nom: Monsieur JULIO PICHON avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 111728 avec statut: 146
# Statut mis à jour avec succès pour Monsieur JULIO PICHON dans Bitrix24
# Vérification du nom: Monsieur KEVIN CLAIN avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 111838 avec statut: 146
# Statut mis à jour avec succès pour Monsieur KEVIN CLAIN dans Bitrix24
# Vérification du nom: Monsieur KEVIN SCHULTZ avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 111924 avec statut: 146
# Statut mis à jour avec succès pour Monsieur KEVIN SCHULTZ dans Bitrix24
# Vérification du nom: Monsieur LENY HINAULT avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 112292 avec statut: 146
# Statut mis à jour avec succès pour Monsieur LENY HINAULT dans Bitrix24
# Vérification du nom: Monsieur LOUIS LE MONIES DE SAGAZAN avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 112546 avec statut: 146
# Statut mis à jour avec succès pour Monsieur LOUIS LE MONIES DE SAGAZAN dans Bitrix24
# Vérification du nom: Monsieur LUDOVIC LUCILLY avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 112726 avec statut: 146
# Statut mis à jour avec succès pour Monsieur LUDOVIC LUCILLY dans Bitrix24
# Vérification du nom: Monsieur LUDOVIC SITALAPRESAD avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 112756 avec statut: 146
# Statut mis à jour avec succès pour Monsieur LUDOVIC SITALAPRESAD dans Bitrix24
# Vérification du nom: Monsieur LUKE EPAIN avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 112784 avec statut: 146
# Statut mis à jour avec succès pour Monsieur LUKE EPAIN dans Bitrix24
# Vérification du nom: Monsieur MANUEL HIRTZLIN avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 112850 avec statut: 146
# Statut mis à jour avec succès pour Monsieur MANUEL HIRTZLIN dans Bitrix24
# Vérification du nom: Monsieur MARVIN LEFORESTIER avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 113124 avec statut: 146
# Statut mis à jour avec succès pour Monsieur MARVIN LEFORESTIER dans Bitrix24
# Vérification du nom: Monsieur MATHIEU FRESLON avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 113218 avec statut: 146
# Statut mis à jour avec succès pour Monsieur MATHIEU FRESLON dans Bitrix24
# Vérification du nom: Monsieur MICHAEL GRAVOUIL avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 113708 avec statut: 146
# Statut mis à jour avec succès pour Monsieur MICHAEL GRAVOUIL dans Bitrix24
# Vérification du nom: Monsieur NICOLAS DEFORGE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 114330 avec statut: 146
# Statut mis à jour avec succès pour Monsieur NICOLAS DEFORGE dans Bitrix24
# Vérification du nom: Monsieur NICOLAS DENIS avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 114338 avec statut: 146
# Statut mis à jour avec succès pour Monsieur NICOLAS DENIS dans Bitrix24
# Vérification du nom: Monsieur OLIVIER CORBANESE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 114758 avec statut: 146
# Statut mis à jour avec succès pour Monsieur OLIVIER CORBANESE dans Bitrix24
# Vérification du nom: Monsieur OLIVIER DILHAC avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 114782 avec statut: 146
# Statut mis à jour avec succès pour Monsieur OLIVIER DILHAC dans Bitrix24
# Vérification du nom: Monsieur OLIVIER VINOLO avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 114952 avec statut: 146
# Statut mis à jour avec succès pour Monsieur OLIVIER VINOLO dans Bitrix24
# Vérification du nom: MONSIEUR OMAR MAHMOUDI avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 114960 avec statut: 146
# Statut mis à jour avec succès pour MONSIEUR OMAR MAHMOUDI dans Bitrix24
# Vérification du nom: Monsieur QUOC-TU NGUYEN avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 116252 avec statut: 146
# Statut mis à jour avec succès pour Monsieur QUOC-TU NGUYEN dans Bitrix24
# Vérification du nom: Monsieur RICHARD BARDIN avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 116530 avec statut: 146
# Statut mis à jour avec succès pour Monsieur RICHARD BARDIN dans Bitrix24
# Vérification du nom: Monsieur ROMAIN GUIET avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 116770 avec statut: 146
# Statut mis à jour avec succès pour Monsieur ROMAIN GUIET dans Bitrix24
# Vérification du nom: Monsieur ROMAIN MORIO avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 116812 avec statut: 146
# Statut mis à jour avec succès pour Monsieur ROMAIN MORIO dans Bitrix24
# Vérification du nom: Monsieur SAMUEL LAURET avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 117054 avec statut: 146
# Statut mis à jour avec succès pour Monsieur SAMUEL LAURET dans Bitrix24
# Vérification du nom: Monsieur SERGE LEBLE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 117422 avec statut: 146
# Statut mis à jour avec succès pour Monsieur SERGE LEBLE dans Bitrix24
# Vérification du nom: Monsieur STEPHANE KNOPES avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 117746 avec statut: 146
# Statut mis à jour avec succès pour Monsieur STEPHANE KNOPES dans Bitrix24
# Vérification du nom: Monsieur STEPHANE PAYET avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 117836 avec statut: 146
# Statut mis à jour avec succès pour Monsieur STEPHANE PAYET dans Bitrix24
# Vérification du nom: Monsieur SYLVAIN DELGENDRE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 118032 avec statut: 146
# Statut mis à jour avec succès pour Monsieur SYLVAIN DELGENDRE dans Bitrix24
# Vérification du nom: Monsieur THIBAULT JACQUES RICARD avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 118250 avec statut: 146
# Statut mis à jour avec succès pour Monsieur THIBAULT JACQUES RICARD dans Bitrix24
# Vérification du nom: Monsieur THIERRY FONTELLES avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 118364 avec statut: 146
# Statut mis à jour avec succès pour Monsieur THIERRY FONTELLES dans Bitrix24
# Vérification du nom: Monsieur THOMAS BREMOND avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 118524 avec statut: 146
# Statut mis à jour avec succès pour Monsieur THOMAS BREMOND dans Bitrix24
# Vérification du nom: Monsieur THOMAS PAYET avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 118622 avec statut: 146
# Statut mis à jour avec succès pour Monsieur THOMAS PAYET dans Bitrix24
# Vérification du nom: Monsieur VINCENT LE ROUX avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 118974 avec statut: 146
# Statut mis à jour avec succès pour Monsieur VINCENT LE ROUX dans Bitrix24
# Vérification du nom: Monsieur XAVIER GILLES avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 119230 avec statut: 146
# Statut mis à jour avec succès pour Monsieur XAVIER GILLES dans Bitrix24
# Vérification du nom: Monsieur YANNICK CROSSOUARD avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 119324 avec statut: 146
# Statut mis à jour avec succès pour Monsieur YANNICK CROSSOUARD dans Bitrix24
# Vérification du nom: MORANCAY BRISSET FLORA - ESSENCI'ELLE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 119826 avec statut: 146
# Statut mis à jour avec succès pour MORANCAY BRISSET FLORA - ESSENCI'ELLE dans Bitrix24
# Vérification du nom: MOREL Francis avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 119886 avec statut: 146
# Statut mis à jour avec succès pour MOREL Francis dans Bitrix24
# Vérification du nom: M. PHILIPPE LE CORRE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 120296 avec statut: 146
# Statut mis à jour avec succès pour M. PHILIPPE LE CORRE dans Bitrix24
# Vérification du nom: MR-ETUDES SASU avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 120584 avec statut: 146
# Statut mis à jour avec succès pour MR-ETUDES SASU dans Bitrix24
# Vérification du nom: MSA LOIRE ATLANTIQUE - VENDEE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 121126 avec statut: 146
# Statut mis à jour avec succès pour MSA LOIRE ATLANTIQUE - VENDEE dans Bitrix24
# Vérification du nom: MUSSARD SINDY EMMANUELLE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 121528 avec statut: 146
# Statut mis à jour avec succès pour MUSSARD SINDY EMMANUELLE dans Bitrix24
# Vérification du nom: MUTUALITE DE LA REUNION SSAM avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 121554 avec statut: 146
# Statut mis à jour avec succès pour MUTUALITE DE LA REUNION SSAM dans Bitrix24
# Vérification du nom: MY BEAUTY LOUNGE & SPA avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 121662 avec statut: 146
# Statut mis à jour avec succès pour MY BEAUTY LOUNGE & SPA dans Bitrix24
# Vérification du nom: MYSTIC BEAUTY HOUSE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 121854 avec statut: 146
# Statut mis à jour avec succès pour MYSTIC BEAUTY HOUSE dans Bitrix24
# Vérification du nom: N3M SOLUTIONS avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 121894 avec statut: 146
# Statut mis à jour avec succès pour N3M SOLUTIONS dans Bitrix24
# Vérification du nom: Nathalie FORMA avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 122302 avec statut: 146
# Statut mis à jour avec succès pour Nathalie FORMA dans Bitrix24
# Vérification du nom: NAZE MARIE CLAUDETTE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 122568 avec statut: 146
# Statut mis à jour avec succès pour NAZE MARIE CLAUDETTE dans Bitrix24
# Vérification du nom: NEOCEAD avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 122756 avec statut: 146
# Statut mis à jour avec succès pour NEOCEAD dans Bitrix24
# Vérification du nom: NET CONCEPT avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 122904 avec statut: 146
# Statut mis à jour avec succès pour NET CONCEPT dans Bitrix24
# Vérification du nom: NICOLAS BROCHARD avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 123268 avec statut: 146
# Statut mis à jour avec succès pour NICOLAS BROCHARD dans Bitrix24
# Vérification du nom: NILGRISS FORMATION SAS avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 123468 avec statut: 146
# Statut mis à jour avec succès pour NILGRISS FORMATION SAS dans Bitrix24
# Vérification du nom: NLDCUT avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 123582 avec statut: 146
# Statut mis à jour avec succès pour NLDCUT dans Bitrix24
# Vérification du nom: NRS CONSULTING avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 124112 avec statut: 146
# Statut mis à jour avec succès pour NRS CONSULTING dans Bitrix24
# Vérification du nom: OFFICE BUSINESS MANAGEMENT avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 124712 avec statut: 146
# Statut mis à jour avec succès pour OFFICE BUSINESS MANAGEMENT dans Bitrix24
# Vérification du nom: OFFICE DES SPORTS ET TEMPS LIBRE DE ST PIERRE REUNION avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 124720 avec statut: 146
# Statut mis à jour avec succès pour OFFICE DES SPORTS ET TEMPS LIBRE DE ST PIERRE REUNION dans Bitrix24
# Vérification du nom: ONATAH avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 125326 avec statut: 146
# Statut mis à jour avec succès pour ONATAH dans Bitrix24
# Vérification du nom: ONSOFT avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 125448 avec statut: 146
# Statut mis à jour avec succès pour ONSOFT dans Bitrix24
# Vérification du nom: OZAMO MAX avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 126520 avec statut: 146
# Statut mis à jour avec succès pour OZAMO MAX dans Bitrix24
# Vérification du nom: PAR ET POUR avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127006 avec statut: 146
# Statut mis à jour avec succès pour PAR ET POUR dans Bitrix24
# Vérification du nom: PARISOT Aude avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127048 avec statut: 146
# Statut mis à jour avec succès pour PARISOT Aude dans Bitrix24
# Vérification du nom: PASCAL FOURNEL avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127280 avec statut: 146
# Statut mis à jour avec succès pour PASCAL FOURNEL dans Bitrix24
# Vérification du nom: PASQUIER Olivier avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127352 avec statut: 146
# Statut mis à jour avec succès pour PASQUIER Olivier dans Bitrix24
# Vérification du nom: PASS LOISIRS2.0 avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127402 avec statut: 146
# Statut mis à jour avec succès pour PASS LOISIRS2.0 dans Bitrix24
# Vérification du nom: PATEL YASMINA avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127434 avec statut: 146
# Statut mis à jour avec succès pour PATEL YASMINA dans Bitrix24
# Vérification du nom: PATRICE GARREAU avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127472 avec statut: 146
# Statut mis à jour avec succès pour PATRICE GARREAU dans Bitrix24
# Vérification du nom: Patricia SAGET avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127518 avec statut: 146
# Statut mis à jour avec succès pour Patricia SAGET dans Bitrix24
# Vérification du nom: PATRICK ROBIN LUTHIER avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127588 avec statut: 146
# Statut mis à jour avec succès pour PATRICK ROBIN LUTHIER dans Bitrix24
# Vérification du nom: PATRY HUARD Christophe Daniel avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127620 avec statut: 146
# Statut mis à jour avec succès pour PATRY HUARD Christophe Daniel dans Bitrix24
# Vérification du nom: PAWAN avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127776 avec statut: 146
# Statut mis à jour avec succès pour PAWAN dans Bitrix24
# Vérification du nom: PAYET OLIVIER CAPTURE COMPETENCE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127804 avec statut: 146
# Statut mis à jour avec succès pour PAYET OLIVIER CAPTURE COMPETENCE dans Bitrix24
# Vérification du nom: PEGASUS ALGORITHMS avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 127974 avec statut: 146
# Statut mis à jour avec succès pour PEGASUS ALGORITHMS dans Bitrix24
# Vérification du nom: PELERINIERE EQUITATION avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 128016 avec statut: 146
# Statut mis à jour avec succès pour PELERINIERE EQUITATION dans Bitrix24
# Vérification du nom: PERLUCERE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 128382 avec statut: 146
# Statut mis à jour avec succès pour PERLUCERE dans Bitrix24
# Vérification du nom: PGA CONSEIL avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 128736 avec statut: 146
# Statut mis à jour avec succès pour PGA CONSEIL dans Bitrix24
# Vérification du nom: PHOEBUS SOLUTIONS avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 129132 avec statut: 146
# Statut mis à jour avec succès pour PHOEBUS SOLUTIONS dans Bitrix24
# Vérification du nom: PIAU MATHILDE avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 129244 avec statut: 146
# Statut mis à jour avec succès pour PIAU MATHILDE dans Bitrix24
# Vérification du nom: PICANTIN Olivier avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 129254 avec statut: 146
# Statut mis à jour avec succès pour PICANTIN Olivier dans Bitrix24
# Vérification du nom: PLUMES DE CIGOGNES avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 129972 avec statut: 146
# Statut mis à jour avec succès pour PLUMES DE CIGOGNES dans Bitrix24
# Vérification du nom: PMO SUSTAINING avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 130040 avec statut: 146
# Statut mis à jour avec succès pour PMO SUSTAINING dans Bitrix24
# Vérification du nom: PRO ARTE GRAPHICA avec statut: Qualiopi
# Envoi de la mise à jour pour l'ID Bitrix: 131138 avec statut: 146
# Statut mis à jour avec succès pour PRO ARTE GRAPHICA dans Bitrix24
# Mise à jour des statuts terminée.
